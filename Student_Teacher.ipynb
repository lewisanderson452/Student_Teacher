# %%
pip install nbconvert[webpdf]
# Out:
# Requirement already satisfied: nbconvert[webpdf] in c:\users\lewis\anaconda3\lib\site-packages (6.1.0)
# Requirement already satisfied: testpath in c:\users\lewis\anaconda3\lib\site-packages (from nbconvert[webpdf]) (0.5.0)
# Requirement already satisfied: entrypoints>=0.2.2 in c:\users\lewis\anaconda3\lib\site-packages (from nbconvert[webpdf]) (0.3)
# Requirement already satisfied: nbformat>=4.4 in c:\users\lewis\anaconda3\lib\site-packages (from nbconvert[webpdf]) (5.1.3)
# Requirement already satisfied: jupyterlab-pygments in c:\users\lewis\anaconda3\lib\site-packages (from nbconvert[webpdf]) (0.1.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\lewis\anaconda3\lib\site-packages (from nbconvert[webpdf]) (1.4.3)
# Requirement already satisfied: jupyter-core in c:\users\lewis\anaconda3\lib\site-packages (from nbconvert[webpdf]) (4.8.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\lewis\anaconda3\lib\site-packages (from nbconvert[webpdf]) (0.8.4)
# Requirement already satisfied: pygments>=2.4.1 in c:\users\lewis\anaconda3\lib\site-packages (from nbconvert[webpdf]) (2.10.0)
# Requirement already satisfied: defusedxml in c:\users\lewis\anaconda3\lib\site-packages (from nbconvert[webpdf]) (0.7.1)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in c:\users\lewis\anaconda3\lib\site-packages (from nbconvert[webpdf]) (0.5.3)
# Requirement already satisfied: traitlets>=5.0 in c:\users\lewis\anaconda3\lib\site-packages (from nbconvert[webpdf]) (5.1.0)
# Requirement already satisfied: bleach in c:\users\lewis\anaconda3\lib\site-packages (from nbconvert[webpdf]) (4.0.0)
# Requirement already satisfied: jinja2>=2.4 in c:\users\lewis\anaconda3\lib\site-packages (from nbconvert[webpdf]) (2.11.3)
# Collecting pyppeteer==0.2.2
#   Downloading pyppeteer-0.2.2-py3-none-any.whl (145 kB)
# Requirement already satisfied: urllib3<2.0.0,>=1.25.8 in c:\users\lewis\anaconda3\lib\site-packages (from pyppeteer==0.2.2->nbconvert[webpdf]) (1.26.7)
# Requirement already satisfied: tqdm<5.0.0,>=4.42.1 in c:\users\lewis\anaconda3\lib\site-packages (from pyppeteer==0.2.2->nbconvert[webpdf]) (4.62.3)
# Collecting pyee<8.0.0,>=7.0.1
#   Downloading pyee-7.0.4-py2.py3-none-any.whl (12 kB)
# Collecting websockets<9.0,>=8.1
#   Downloading websockets-8.1.tar.gz (58 kB)
# Requirement already satisfied: appdirs<2.0.0,>=1.4.3 in c:\users\lewis\anaconda3\lib\site-packages (from pyppeteer==0.2.2->nbconvert[webpdf]) (1.4.4)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\lewis\anaconda3\lib\site-packages (from jinja2>=2.4->nbconvert[webpdf]) (1.1.1)
# Requirement already satisfied: async-generator in c:\users\lewis\anaconda3\lib\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert[webpdf]) (1.10)
# Requirement already satisfied: jupyter-client>=6.1.5 in c:\users\lewis\anaconda3\lib\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert[webpdf]) (6.1.12)
# Requirement already satisfied: nest-asyncio in c:\users\lewis\anaconda3\lib\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert[webpdf]) (1.5.1)
# Requirement already satisfied: tornado>=4.1 in c:\users\lewis\anaconda3\lib\site-packages (from jupyter-client>=6.1.5->nbclient<0.6.0,>=0.5.0->nbconvert[webpdf]) (6.1)
# Requirement already satisfied: python-dateutil>=2.1 in c:\users\lewis\anaconda3\lib\site-packages (from jupyter-client>=6.1.5->nbclient<0.6.0,>=0.5.0->nbconvert[webpdf]) (2.8.2)
# Requirement already satisfied: pyzmq>=13 in c:\users\lewis\anaconda3\lib\site-packages (from jupyter-client>=6.1.5->nbclient<0.6.0,>=0.5.0->nbconvert[webpdf]) (22.2.1)
# Requirement already satisfied: pywin32>=1.0 in c:\users\lewis\anaconda3\lib\site-packages (from jupyter-core->nbconvert[webpdf]) (227)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in c:\users\lewis\anaconda3\lib\site-packages (from nbformat>=4.4->nbconvert[webpdf]) (3.2.0)
# Requirement already satisfied: ipython-genutils in c:\users\lewis\anaconda3\lib\site-packages (from nbformat>=4.4->nbconvert[webpdf]) (0.2.0)
# Requirement already satisfied: setuptools in c:\users\lewis\anaconda3\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.4->nbconvert[webpdf]) (58.0.4)
# Requirement already satisfied: six>=1.11.0 in c:\users\lewis\anaconda3\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.4->nbconvert[webpdf]) (1.16.0)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\lewis\anaconda3\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.4->nbconvert[webpdf]) (21.2.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in c:\users\lewis\anaconda3\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.4->nbconvert[webpdf]) (0.18.0)
# Requirement already satisfied: colorama in c:\users\lewis\anaconda3\lib\site-packages (from tqdm<5.0.0,>=4.42.1->pyppeteer==0.2.2->nbconvert[webpdf]) (0.4.4)
# Requirement already satisfied: webencodings in c:\users\lewis\anaconda3\lib\site-packages (from bleach->nbconvert[webpdf]) (0.5.1)
# Requirement already satisfied: packaging in c:\users\lewis\anaconda3\lib\site-packages (from bleach->nbconvert[webpdf]) (21.0)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\lewis\anaconda3\lib\site-packages (from packaging->bleach->nbconvert[webpdf]) (3.0.4)
# Building wheels for collected packages: websockets
#   Building wheel for websockets (setup.py): started
#   Building wheel for websockets (setup.py): finished with status 'done'
#   Created wheel for websockets: filename=websockets-8.1-cp39-cp39-win_amd64.whl size=62758 sha256=29b2a51a28f3332905debe595cda7c096121d5798c9c181602b868574dcb21ff
#   Stored in directory: c:\users\lewis\appdata\local\pip\cache\wheels\d8\b9\a0\b97b211aeda2ebd6ac2e43fc300d308dbf1f9df520ed390cae
# Successfully built websockets
# Installing collected packages: websockets, pyee, pyppeteer
# Successfully installed pyee-7.0.4 pyppeteer-0.2.2 websockets-8.1
# Note: you may need to restart the kernel to use updated packages.

# %%
conda install -c conda-forge pyppeteer
# Out:
# ^C
#
# Note: you may need to restart the kernel to use updated packages.

# %%
"""
    Imports: convert.py  (Custom parquet-to-csv convertor)
    Dependancies: json
    
    Procedure:
        Choose whether to convert file 
        Enter name of students csv file
        Enter name of teachers csv file
        Enter name of output json file
        Data is processed and stored in output json file
        
"""

from convert import convert
import json

# Function to parse teacher data to select certain teacher for student
def get_teacher_data(id,data):
    for x in data:
        if x[-1] == id:
            res = {}
            res["ID"] = x[0]
            res["First Name"] = x[1]
            res["Last Name"] = x[2]
            res["Email"] = x[3]
            res["SSN"] = x[4]
            res["Address"] = x[5]
            return res
    
    return 0 # Not Found

# %%
# Function get students data from file
def student_file(name):
    try:
        with open(f"{name}", "r") as file:
            students = file.read().strip().split("\n")[1:]
            students = [x.split("_") for x in students]
            return students
    except Exception as e:
        print(e)
        return 0

# %%
# Function to get teachers data from file
def teacher_file(name):
    try:
        with open(f"{name}", "r") as file:
            teachers = file.read().split("\n")[1:]
            teachers = [x.split(",") for x in teachers]
            return teachers
    except Exception as e:
        print(e)
        return 0

# %%
# Function to process student and techers data into json
def process_data(students,teachers):
    output = {}
    try:
        for x in students:
            data = {}
            data["First Name"] = x[1]
            data["Last Name"] = x[2]
            data["Email"] = x[3]
            data["SSN"] = x[4]
            data["Address"] = x[5]
            data["CID"] = x[6]
            data["Teacher"] = get_teacher_data(x[6], teachers)
            output[x[0]] = data
        return output
    except Exception as e:
        print(e)
        print("Data not complete")
        return 0

# %%
# Function to output json data to file
def save_data(name,output):
    try:
        with open(f"{name}", "w") as file:
            str_out = json.dumps(output)
            file.write(str_out)
            return 1 # Success
    except Exception as e:
        print(e)
        return 0 # Error
    
if __name__ == "__main__":
    
    choice = input("Enter Y to convert parquet file or enter any key to continue: ")
    
    if choice.lower() == 'y':
        convert()
    
    s = input("Enter name of students csv file: ")
    if not s.endswith(".csv"):
        s += ".csv"
    students = student_file(s)
    
    t = input("Enter name of teachers csv file: ")
    if not t.endswith(".csv"):
        t += ".csv"
    teachers = teacher_file(t)

    output = process_data(students,teachers)
    
    o = input("Enter name of output json file: ")
    if not s.endswith(".json"):
        o += ".json"
    save_data(o,output)

# This code will ask you if there is a parquet file if Y 
# Then type the pathway to it
# if no type the csv file
# after type the name you want to give the output file
# then type the student csv file pathway
# Then type the teachers csv file pathway that was created by the first step
# then enter the desired json file name
# Out:
# Enter Y to convert parquet file or enter any key to continue: Y
# Enter parquet file path: teachers
# Enter name of new output file: Teacher
# File Converted
#
#
# Enter name of students csv file: students
# Enter name of teachers csv file: Teacher
# Enter name of output json file: Student-Teacher

# %%
import json

# %%
# Opening JSON file
with open('Student-Teacher.json','r') as S:
    data = json.load(S)
data
# Out:
# {'1': {'First Name': 'Dniren',
#   'Last Name': 'Dewbury',
#   'Email': 'ddewbury0@illinois.edu',
#   'SSN': '498-19-2152',
#   'Address': '63083 Jana Point',
#   'CID': '08-2046381',
#   'Teacher': {'ID': '51-3016916',
#    'First Name': 'Jessa',
#    'Last Name': 'Gibbs',
#    'Email': 'jgibbs0@bandcamp.com',
#    'SSN': '733-04-9225',
#    'Address': '32 Ridgeview Circle'}},
#  '2': {'First Name': 'Marten',
#   'Last Name': 'Catanheira',
#   'Email': 'mcatanheira1@nyu.edu',
#   'SSN': '734-61-0692',
#   'Address': '7 Lawn Alley',
#   'CID': '57-9105495',
#   'Teacher': {'ID': '03-1224783',
#    'First Name': 'Tate',
#    'Last Name': 'Weekley',
#    'Email': 'tweekley1@nps.gov',
#    'SSN': '392-55-5726',
#    'Address': '5 Lawn Alley'}},
#  '3': {'First Name': 'Shae',
#   'Last Name': 'Olivet',
#   'Email': 'solivet2@guardian.co.uk',
#   'SSN': '633-18-3236',
#   'Address': '5 Golf View Alley',
#   'CID': '76-3364242',
#   'Teacher': {'ID': '33-3280005',
#    'First Name': 'Trenna',
#    'Last Name': 'Chasney',
#    'Email': 'tchasney2@vimeo.com',
#    'SSN': '608-97-4356',
#    'Address': '4 Sunbrook Crossing'}},
#  '4': {'First Name': 'Evin',
#   'Last Name': 'Garioch',
#   'Email': 'egarioch3@netscape.com',
#   'SSN': '712-34-9211',
#   'Address': '77304 Calypso Lane',
#   'CID': '32-3782498',
#   'Teacher': {'ID': '19-7014703',
#    'First Name': 'Rabbi',
#    'Last Name': 'McGuinness',
#    'Email': 'rmcguinness3@bloglines.com',
#    'SSN': '548-85-3011',
#    'Address': '12 Sachtjen Street'}},
#  '5': {'First Name': 'Kathlin',
#   'Last Name': 'Mauser',
#   'Email': 'kmauser4@dropbox.com',
#   'SSN': '810-52-9400',
#   'Address': '62 Anniversary Alley',
#   'CID': '50-4537323',
#   'Teacher': {'ID': '76-7924467',
#    'First Name': 'Amalle',
#    'Last Name': 'Toffetto',
#    'Email': 'atoffetto4@ftc.gov',
#    'SSN': '598-24-7742',
#    'Address': '08 Anzinger Parkway'}},
#  '6': {'First Name': 'Kristy',
#   'Last Name': 'Dorrance',
#   'Email': 'kdorrance5@xinhuanet.com',
#   'SSN': '439-81-0666',
#   'Address': '3 Doe Crossing Junction',
#   'CID': '83-0287469',
#   'Teacher': {'ID': '99-8422756',
#    'First Name': 'Leilah',
#    'Last Name': 'Parlatt',
#    'Email': 'lparlatt5@about.com',
#    'SSN': '599-97-9346',
#    'Address': '7948 Autumn Leaf Plaza'}},
#  '7': {'First Name': 'Lissa',
#   'Last Name': 'Peffer',
#   'Email': 'lpeffer6@state.gov',
#   'SSN': '682-17-3718',
#   'Address': '5 Dovetail Parkway',
#   'CID': '86-8652269',
#   'Teacher': {'ID': '52-2884288',
#    'First Name': 'Pancho',
#    'Last Name': 'Dearnley',
#    'Email': 'pdearnley6@google.com.hk',
#    'SSN': '718-13-6984',
#    'Address': '36 Portage Road'}},
#  '8': {'First Name': 'Imelda',
#   'Last Name': 'Darcy',
#   'Email': 'idarcy7@so-net.ne.jp',
#   'SSN': '254-24-6680',
#   'Address': '3110 Melrose Hill',
#   'CID': '76-2796204',
#   'Teacher': {'ID': '31-0093154',
#    'First Name': 'Tallie',
#    'Last Name': 'Folker',
#    'Email': 'tfolker7@ftc.gov',
#    'SSN': '674-01-4183',
#    'Address': '438 Tony Road'}},
#  '9': {'First Name': 'La verne',
#   'Last Name': 'Pummell',
#   'Email': 'lpummell8@vimeo.com',
#   'SSN': '159-15-5319',
#   'Address': '9 Bowman Lane',
#   'CID': '02-4026245',
#   'Teacher': {'ID': '38-5781049',
#    'First Name': 'Elsa',
#    'Last Name': 'Corps',
#    'Email': 'ecorps8@aboutads.info',
#    'SSN': '490-18-7796',
#    'Address': '706 Garrison Lane'}},
#  '10': {'First Name': 'Shelley',
#   'Last Name': 'Harnell',
#   'Email': 'sharnell9@tumblr.com',
#   'SSN': '268-05-0795',
#   'Address': '32 Vidon Circle',
#   'CID': '52-0676084',
#   'Teacher': {'ID': '58-8777255',
#    'First Name': 'Tracey',
#    'Last Name': 'Scoyles',
#    'Email': 'tscoyles9@biblegateway.com',
#    'SSN': '612-85-3002',
#    'Address': '7 Kennedy Junction'}},
#  '11': {'First Name': 'Willie',
#   'Last Name': 'Leyre',
#   'Email': 'wleyrea@1und1.de',
#   'SSN': '806-50-5807',
#   'Address': '07 Hanson Parkway',
#   'CID': '08-2046381',
#   'Teacher': {'ID': '51-3016916',
#    'First Name': 'Jessa',
#    'Last Name': 'Gibbs',
#    'Email': 'jgibbs0@bandcamp.com',
#    'SSN': '733-04-9225',
#    'Address': '32 Ridgeview Circle'}},
#  '12': {'First Name': 'Zach',
#   'Last Name': 'Gadie',
#   'Email': 'zgadieb@blinklist.com',
#   'SSN': '766-84-4897',
#   'Address': '73282 Fairview Drive',
#   'CID': '57-9105495',
#   'Teacher': {'ID': '03-1224783',
#    'First Name': 'Tate',
#    'Last Name': 'Weekley',
#    'Email': 'tweekley1@nps.gov',
#    'SSN': '392-55-5726',
#    'Address': '5 Lawn Alley'}},
#  '13': {'First Name': 'Shurlock',
#   'Last Name': 'Nary',
#   'Email': 'snaryc@wired.com',
#   'SSN': '133-94-0271',
#   'Address': '90 Melrose Park',
#   'CID': '76-3364242',
#   'Teacher': {'ID': '33-3280005',
#    'First Name': 'Trenna',
#    'Last Name': 'Chasney',
#    'Email': 'tchasney2@vimeo.com',
#    'SSN': '608-97-4356',
#    'Address': '4 Sunbrook Crossing'}},
#  '14': {'First Name': 'Mauricio',
#   'Last Name': 'Treker',
#   'Email': 'mtrekerd@sohu.com',
#   'SSN': '670-97-8462',
#   'Address': '361 Milwaukee Court',
#   'CID': '32-3782498',
#   'Teacher': {'ID': '19-7014703',
#    'First Name': 'Rabbi',
#    'Last Name': 'McGuinness',
#    'Email': 'rmcguinness3@bloglines.com',
#    'SSN': '548-85-3011',
#    'Address': '12 Sachtjen Street'}},
#  '15': {'First Name': 'Dionis',
#   'Last Name': 'Kike',
#   'Email': 'dkikee@japanpost.jp',
#   'SSN': '585-48-5347',
#   'Address': '8591 Swallow Crossing',
#   'CID': '50-4537323',
#   'Teacher': {'ID': '76-7924467',
#    'First Name': 'Amalle',
#    'Last Name': 'Toffetto',
#    'Email': 'atoffetto4@ftc.gov',
#    'SSN': '598-24-7742',
#    'Address': '08 Anzinger Parkway'}},
#  '16': {'First Name': 'Philbert',
#   'Last Name': 'Gillbanks',
#   'Email': 'pgillbanksf@vimeo.com',
#   'SSN': '862-75-2865',
#   'Address': '4 Barby Way',
#   'CID': '83-0287469',
#   'Teacher': {'ID': '99-8422756',
#    'First Name': 'Leilah',
#    'Last Name': 'Parlatt',
#    'Email': 'lparlatt5@about.com',
#    'SSN': '599-97-9346',
#    'Address': '7948 Autumn Leaf Plaza'}},
#  '17': {'First Name': 'Dan',
#   'Last Name': 'Nicklen',
#   'Email': 'dnickleng@google.ca',
#   'SSN': '525-65-0824',
#   'Address': '621 Huxley Trail',
#   'CID': '86-8652269',
#   'Teacher': {'ID': '52-2884288',
#    'First Name': 'Pancho',
#    'Last Name': 'Dearnley',
#    'Email': 'pdearnley6@google.com.hk',
#    'SSN': '718-13-6984',
#    'Address': '36 Portage Road'}},
#  '18': {'First Name': 'Hunfredo',
#   'Last Name': 'Bavester',
#   'Email': 'hbavesterh@wordpress.org',
#   'SSN': '590-10-0726',
#   'Address': '61 Kim Road',
#   'CID': '76-2796204',
#   'Teacher': {'ID': '31-0093154',
#    'First Name': 'Tallie',
#    'Last Name': 'Folker',
#    'Email': 'tfolker7@ftc.gov',
#    'SSN': '674-01-4183',
#    'Address': '438 Tony Road'}},
#  '19': {'First Name': 'Teador',
#   'Last Name': 'Skinner',
#   'Email': 'tskinneri@google.com.hk',
#   'SSN': '341-72-2225',
#   'Address': '50 Oak Trail',
#   'CID': '02-4026245',
#   'Teacher': {'ID': '38-5781049',
#    'First Name': 'Elsa',
#    'Last Name': 'Corps',
#    'Email': 'ecorps8@aboutads.info',
#    'SSN': '490-18-7796',
#    'Address': '706 Garrison Lane'}},
#  '20': {'First Name': 'Rubin',
#   'Last Name': 'Stainburn',
#   'Email': 'rstainburnj@fastcompany.com',
#   'SSN': '332-61-2507',
#   'Address': '8757 Sachtjen Park',
#   'CID': '52-0676084',
#   'Teacher': {'ID': '58-8777255',
#    'First Name': 'Tracey',
#    'Last Name': 'Scoyles',
#    'Email': 'tscoyles9@biblegateway.com',
#    'SSN': '612-85-3002',
#    'Address': '7 Kennedy Junction'}},
#  '21': {'First Name': 'Channa',
#   'Last Name': 'Michin',
#   'Email': 'cmichink@washington.edu',
#   'SSN': '251-43-3876',
#   'Address': '73222 Blackbird Alley',
#   'CID': '08-2046381',
#   'Teacher': {'ID': '51-3016916',
#    'First Name': 'Jessa',
#    'Last Name': 'Gibbs',
#    'Email': 'jgibbs0@bandcamp.com',
#    'SSN': '733-04-9225',
#    'Address': '32 Ridgeview Circle'}},
#  '22': {'First Name': 'Valerye',
#   'Last Name': 'Cassella',
#   'Email': 'vcassellal@google.ru',
#   'SSN': '256-75-2501',
#   'Address': '4687 Troy Alley',
#   'CID': '57-9105495',
#   'Teacher': {'ID': '03-1224783',
#    'First Name': 'Tate',
#    'Last Name': 'Weekley',
#    'Email': 'tweekley1@nps.gov',
#    'SSN': '392-55-5726',
#    'Address': '5 Lawn Alley'}},
#  '23': {'First Name': 'Wilona',
#   'Last Name': 'Pett',
#   'Email': 'wpettm@springer.com',
#   'SSN': '605-59-1543',
#   'Address': '86 Carpenter Drive',
#   'CID': '76-3364242',
#   'Teacher': {'ID': '33-3280005',
#    'First Name': 'Trenna',
#    'Last Name': 'Chasney',
#    'Email': 'tchasney2@vimeo.com',
#    'SSN': '608-97-4356',
#    'Address': '4 Sunbrook Crossing'}},
#  '24': {'First Name': 'Cullan',
#   'Last Name': 'Mattielli',
#   'Email': 'cmattiellin@domainmarket.com',
#   'SSN': '267-70-3020',
#   'Address': '95 Moland Alley',
#   'CID': '32-3782498',
#   'Teacher': {'ID': '19-7014703',
#    'First Name': 'Rabbi',
#    'Last Name': 'McGuinness',
#    'Email': 'rmcguinness3@bloglines.com',
#    'SSN': '548-85-3011',
#    'Address': '12 Sachtjen Street'}},
#  '25': {'First Name': 'Kinny',
#   'Last Name': 'Wombwell',
#   'Email': 'kwombwello@hubpages.com',
#   'SSN': '588-62-7729',
#   'Address': '8 Kennedy Alley',
#   'CID': '50-4537323',
#   'Teacher': {'ID': '76-7924467',
#    'First Name': 'Amalle',
#    'Last Name': 'Toffetto',
#    'Email': 'atoffetto4@ftc.gov',
#    'SSN': '598-24-7742',
#    'Address': '08 Anzinger Parkway'}},
#  '26': {'First Name': 'Silvie',
#   'Last Name': 'Dixcey',
#   'Email': 'sdixceyp@rambler.ru',
#   'SSN': '704-88-6879',
#   'Address': '17068 Division Alley',
#   'CID': '83-0287469',
#   'Teacher': {'ID': '99-8422756',
#    'First Name': 'Leilah',
#    'Last Name': 'Parlatt',
#    'Email': 'lparlatt5@about.com',
#    'SSN': '599-97-9346',
#    'Address': '7948 Autumn Leaf Plaza'}},
#  '27': {'First Name': 'Libbi',
#   'Last Name': 'Doghartie',
#   'Email': 'ldoghartieq@4shared.com',
#   'SSN': '834-92-5391',
#   'Address': '0 Lotheville Plaza',
#   'CID': '86-8652269',
#   'Teacher': {'ID': '52-2884288',
#    'First Name': 'Pancho',
#    'Last Name': 'Dearnley',
#    'Email': 'pdearnley6@google.com.hk',
#    'SSN': '718-13-6984',
#    'Address': '36 Portage Road'}},
#  '28': {'First Name': 'Gerhardine',
#   'Last Name': 'Chasemoore',
#   'Email': 'gchasemoorer@clickbank.net',
#   'SSN': '500-37-1153',
#   'Address': '11769 Bowman Lane',
#   'CID': '76-2796204',
#   'Teacher': {'ID': '31-0093154',
#    'First Name': 'Tallie',
#    'Last Name': 'Folker',
#    'Email': 'tfolker7@ftc.gov',
#    'SSN': '674-01-4183',
#    'Address': '438 Tony Road'}},
#  '29': {'First Name': 'Mamie',
#   'Last Name': 'Drury',
#   'Email': 'mdrurys@sbwire.com',
#   'SSN': '192-06-7369',
#   'Address': '334 Killdeer Terrace',
#   'CID': '02-4026245',
#   'Teacher': {'ID': '38-5781049',
#    'First Name': 'Elsa',
#    'Last Name': 'Corps',
#    'Email': 'ecorps8@aboutads.info',
#    'SSN': '490-18-7796',
#    'Address': '706 Garrison Lane'}},
#  '30': {'First Name': 'Ches',
#   'Last Name': 'Davidove',
#   'Email': 'cdavidovet@studiopress.com',
#   'SSN': '888-77-5522',
#   'Address': '494 Dayton Junction',
#   'CID': '52-0676084',
#   'Teacher': {'ID': '58-8777255',
#    'First Name': 'Tracey',
#    'Last Name': 'Scoyles',
#    'Email': 'tscoyles9@biblegateway.com',
#    'SSN': '612-85-3002',
#    'Address': '7 Kennedy Junction'}},
#  '31': {'First Name': 'Alyssa',
#   'Last Name': 'Humpherston',
#   'Email': 'ahumpherstonu@arstechnica.com',
#   'SSN': '641-50-0083',
#   'Address': '5611 3rd Center',
#   'CID': '08-2046381',
#   'Teacher': {'ID': '51-3016916',
#    'First Name': 'Jessa',
#    'Last Name': 'Gibbs',
#    'Email': 'jgibbs0@bandcamp.com',
#    'SSN': '733-04-9225',
#    'Address': '32 Ridgeview Circle'}},
#  '32': {'First Name': 'Selle',
#   'Last Name': 'Le Clercq',
#   'Email': 'sleclercqv@google.ru',
#   'SSN': '875-86-2822',
#   'Address': '0 Vermont Circle',
#   'CID': '57-9105495',
#   'Teacher': {'ID': '03-1224783',
#    'First Name': 'Tate',
#    'Last Name': 'Weekley',
#    'Email': 'tweekley1@nps.gov',
#    'SSN': '392-55-5726',
#    'Address': '5 Lawn Alley'}},
#  '33': {'First Name': 'Denna',
#   'Last Name': 'Petche',
#   'Email': 'dpetchew@newsvine.com',
#   'SSN': '374-39-2001',
#   'Address': '12908 Almo Junction',
#   'CID': '76-3364242',
#   'Teacher': {'ID': '33-3280005',
#    'First Name': 'Trenna',
#    'Last Name': 'Chasney',
#    'Email': 'tchasney2@vimeo.com',
#    'SSN': '608-97-4356',
#    'Address': '4 Sunbrook Crossing'}},
#  '34': {'First Name': 'Brunhilda',
#   'Last Name': 'Mussotti',
#   'Email': 'bmussottix@bloomberg.com',
#   'SSN': '333-52-5864',
#   'Address': '7327 Chinook Lane',
#   'CID': '32-3782498',
#   'Teacher': {'ID': '19-7014703',
#    'First Name': 'Rabbi',
#    'Last Name': 'McGuinness',
#    'Email': 'rmcguinness3@bloglines.com',
#    'SSN': '548-85-3011',
#    'Address': '12 Sachtjen Street'}},
#  '35': {'First Name': 'Mahalia',
#   'Last Name': 'de Leon',
#   'Email': 'mdeleony@mapy.cz',
#   'SSN': '140-77-1423',
#   'Address': '883 3rd Hill',
#   'CID': '50-4537323',
#   'Teacher': {'ID': '76-7924467',
#    'First Name': 'Amalle',
#    'Last Name': 'Toffetto',
#    'Email': 'atoffetto4@ftc.gov',
#    'SSN': '598-24-7742',
#    'Address': '08 Anzinger Parkway'}},
#  '36': {'First Name': 'Harmon',
#   'Last Name': 'Maciocia',
#   'Email': 'hmaciociaz@spiegel.de',
#   'SSN': '649-28-1859',
#   'Address': '8270 Dovetail Crossing',
#   'CID': '83-0287469',
#   'Teacher': {'ID': '99-8422756',
#    'First Name': 'Leilah',
#    'Last Name': 'Parlatt',
#    'Email': 'lparlatt5@about.com',
#    'SSN': '599-97-9346',
#    'Address': '7948 Autumn Leaf Plaza'}},
#  '37': {'First Name': 'Timothee',
#   'Last Name': 'Hutley',
#   'Email': 'thutley10@skyrock.com',
#   'SSN': '604-02-7596',
#   'Address': '61 South Hill',
#   'CID': '86-8652269',
#   'Teacher': {'ID': '52-2884288',
#    'First Name': 'Pancho',
#    'Last Name': 'Dearnley',
#    'Email': 'pdearnley6@google.com.hk',
#    'SSN': '718-13-6984',
#    'Address': '36 Portage Road'}},
#  '38': {'First Name': 'Ephrem',
#   'Last Name': 'Rablin',
#   'Email': 'erablin11@gizmodo.com',
#   'SSN': '316-61-1404',
#   'Address': '63787 Fairview Avenue',
#   'CID': '76-2796204',
#   'Teacher': {'ID': '31-0093154',
#    'First Name': 'Tallie',
#    'Last Name': 'Folker',
#    'Email': 'tfolker7@ftc.gov',
#    'SSN': '674-01-4183',
#    'Address': '438 Tony Road'}},
#  '39': {'First Name': 'Parsifal',
#   'Last Name': 'Cleaver',
#   'Email': 'pcleaver12@furl.net',
#   'SSN': '437-08-0048',
#   'Address': '072 Garrison Lane',
#   'CID': '02-4026245',
#   'Teacher': {'ID': '38-5781049',
#    'First Name': 'Elsa',
#    'Last Name': 'Corps',
#    'Email': 'ecorps8@aboutads.info',
#    'SSN': '490-18-7796',
#    'Address': '706 Garrison Lane'}},
#  '40': {'First Name': 'Lyssa',
#   'Last Name': 'Barhams',
#   'Email': 'lbarhams13@theglobeandmail.com',
#   'SSN': '127-48-1249',
#   'Address': '0644 American Ash Park',
#   'CID': '52-0676084',
#   'Teacher': {'ID': '58-8777255',
#    'First Name': 'Tracey',
#    'Last Name': 'Scoyles',
#    'Email': 'tscoyles9@biblegateway.com',
#    'SSN': '612-85-3002',
#    'Address': '7 Kennedy Junction'}},
#  '41': {'First Name': 'Berkeley',
#   'Last Name': 'Coushe',
#   'Email': 'bcoushe14@bandcamp.com',
#   'SSN': '827-61-9263',
#   'Address': '8 Troy Street',
#   'CID': '08-2046381',
#   'Teacher': {'ID': '51-3016916',
#    'First Name': 'Jessa',
#    'Last Name': 'Gibbs',
#    'Email': 'jgibbs0@bandcamp.com',
#    'SSN': '733-04-9225',
#    'Address': '32 Ridgeview Circle'}},
#  '42': {'First Name': 'Salli',
#   'Last Name': 'Couronne',
#   'Email': 'scouronne15@goo.ne.jp',
#   'SSN': '589-30-2134',
#   'Address': '60959 Birchwood Court',
#   'CID': '57-9105495',
#   'Teacher': {'ID': '03-1224783',
#    'First Name': 'Tate',
#    'Last Name': 'Weekley',
#    'Email': 'tweekley1@nps.gov',
#    'SSN': '392-55-5726',
#    'Address': '5 Lawn Alley'}},
#  '43': {'First Name': 'Georges',
#   'Last Name': 'Colby',
#   'Email': 'gcolby16@sbwire.com',
#   'SSN': '472-25-0789',
#   'Address': '0 American Ash Street',
#   'CID': '76-3364242',
#   'Teacher': {'ID': '33-3280005',
#    'First Name': 'Trenna',
#    'Last Name': 'Chasney',
#    'Email': 'tchasney2@vimeo.com',
#    'SSN': '608-97-4356',
#    'Address': '4 Sunbrook Crossing'}},
#  '44': {'First Name': 'Giordano',
#   'Last Name': 'Fellgate',
#   'Email': 'gfellgate17@noaa.gov',
#   'SSN': '385-97-6089',
#   'Address': '34307 Mallory Junction',
#   'CID': '32-3782498',
#   'Teacher': {'ID': '19-7014703',
#    'First Name': 'Rabbi',
#    'Last Name': 'McGuinness',
#    'Email': 'rmcguinness3@bloglines.com',
#    'SSN': '548-85-3011',
#    'Address': '12 Sachtjen Street'}},
#  '45': {'First Name': 'Olympe',
#   'Last Name': 'Praill',
#   'Email': 'opraill18@biglobe.ne.jp',
#   'SSN': '352-47-3706',
#   'Address': '3932 Spaight Pass',
#   'CID': '50-4537323',
#   'Teacher': {'ID': '76-7924467',
#    'First Name': 'Amalle',
#    'Last Name': 'Toffetto',
#    'Email': 'atoffetto4@ftc.gov',
#    'SSN': '598-24-7742',
#    'Address': '08 Anzinger Parkway'}},
#  '46': {'First Name': 'Mireille',
#   'Last Name': 'Lampen',
#   'Email': 'mlampen19@bizjournals.com',
#   'SSN': '469-61-5560',
#   'Address': '4 Alpine Junction',
#   'CID': '83-0287469',
#   'Teacher': {'ID': '99-8422756',
#    'First Name': 'Leilah',
#    'Last Name': 'Parlatt',
#    'Email': 'lparlatt5@about.com',
#    'SSN': '599-97-9346',
#    'Address': '7948 Autumn Leaf Plaza'}},
#  '47': {'First Name': 'Gustave',
#   'Last Name': 'Estrella',
#   'Email': 'gestrella1a@loc.gov',
#   'SSN': '413-05-5481',
#   'Address': '6 Laurel Lane',
#   'CID': '86-8652269',
#   'Teacher': {'ID': '52-2884288',
#    'First Name': 'Pancho',
#    'Last Name': 'Dearnley',
#    'Email': 'pdearnley6@google.com.hk',
#    'SSN': '718-13-6984',
#    'Address': '36 Portage Road'}},
#  '48': {'First Name': 'Sibylla',
#   'Last Name': 'Edger',
#   'Email': 'sedger1b@skype.com',
#   'SSN': '571-15-4539',
#   'Address': '8404 Loftsgordon Road',
#   'CID': '76-2796204',
#   'Teacher': {'ID': '31-0093154',
#    'First Name': 'Tallie',
#    'Last Name': 'Folker',
#    'Email': 'tfolker7@ftc.gov',
#    'SSN': '674-01-4183',
#    'Address': '438 Tony Road'}},
#  '49': {'First Name': 'Debora',
#   'Last Name': 'Rannigan',
#   'Email': 'drannigan1c@hexun.com',
#   'SSN': '735-99-0128',
#   'Address': '0638 Thackeray Park',
#   'CID': '02-4026245',
#   'Teacher': {'ID': '38-5781049',
#    'First Name': 'Elsa',
#    'Last Name': 'Corps',
#    'Email': 'ecorps8@aboutads.info',
#    'SSN': '490-18-7796',
#    'Address': '706 Garrison Lane'}},
#  '50': {'First Name': 'Tracee',
#   'Last Name': 'Marchetti',
#   'Email': 'tmarchetti1d@hao123.com',
#   'SSN': '332-95-9316',
#   'Address': '1232 Waubesa Avenue',
#   'CID': '52-0676084',
#   'Teacher': {'ID': '58-8777255',
#    'First Name': 'Tracey',
#    'Last Name': 'Scoyles',
#    'Email': 'tscoyles9@biblegateway.com',
#    'SSN': '612-85-3002',
#    'Address': '7 Kennedy Junction'}},
#  '51': {'First Name': 'Lesli',
#   'Last Name': 'Iozefovich',
#   'Email': 'liozefovich1e@bbb.org',
#   'SSN': '321-14-1791',
#   'Address': '61 Cardinal Hill',
#   'CID': '08-2046381',
#   'Teacher': {'ID': '51-3016916',
#    'First Name': 'Jessa',
#    'Last Name': 'Gibbs',
#    'Email': 'jgibbs0@bandcamp.com',
#    'SSN': '733-04-9225',
#    'Address': '32 Ridgeview Circle'}},
#  '52': {'First Name': 'Quinlan',
#   'Last Name': 'Tran',
#   'Email': 'qtran1f@i2i.jp',
#   'SSN': '402-41-2121',
#   'Address': '380 Lakewood Hill',
#   'CID': '57-9105495',
#   'Teacher': {'ID': '03-1224783',
#    'First Name': 'Tate',
#    'Last Name': 'Weekley',
#    'Email': 'tweekley1@nps.gov',
#    'SSN': '392-55-5726',
#    'Address': '5 Lawn Alley'}},
#  '53': {'First Name': 'Ruddie',
#   'Last Name': 'Shepperd',
#   'Email': 'rshepperd1g@lycos.com',
#   'SSN': '414-57-8538',
#   'Address': '2858 American Ash Road',
#   'CID': '76-3364242',
#   'Teacher': {'ID': '33-3280005',
#    'First Name': 'Trenna',
#    'Last Name': 'Chasney',
#    'Email': 'tchasney2@vimeo.com',
#    'SSN': '608-97-4356',
#    'Address': '4 Sunbrook Crossing'}},
#  '54': {'First Name': 'Fremont',
#   'Last Name': 'Strevens',
#   'Email': 'fstrevens1h@howstuffworks.com',
#   'SSN': '885-42-7828',
#   'Address': '596 Holy Cross Trail',
#   'CID': '32-3782498',
#   'Teacher': {'ID': '19-7014703',
#    'First Name': 'Rabbi',
#    'Last Name': 'McGuinness',
#    'Email': 'rmcguinness3@bloglines.com',
#    'SSN': '548-85-3011',
#    'Address': '12 Sachtjen Street'}},
#  '55': {'First Name': 'Aluino',
#   'Last Name': 'Readman',
#   'Email': 'areadman1i@freewebs.com',
#   'SSN': '777-58-7455',
#   'Address': '35560 Sloan Junction',
#   'CID': '50-4537323',
#   'Teacher': {'ID': '76-7924467',
#    'First Name': 'Amalle',
#    'Last Name': 'Toffetto',
#    'Email': 'atoffetto4@ftc.gov',
#    'SSN': '598-24-7742',
#    'Address': '08 Anzinger Parkway'}},
#  '56': {'First Name': 'Keith',
#   'Last Name': 'Allot',
#   'Email': 'kallot1j@blogs.com',
#   'SSN': '878-37-7661',
#   'Address': '6257 Rieder Trail',
#   'CID': '83-0287469',
#   'Teacher': {'ID': '99-8422756',
#    'First Name': 'Leilah',
#    'Last Name': 'Parlatt',
#    'Email': 'lparlatt5@about.com',
#    'SSN': '599-97-9346',
#    'Address': '7948 Autumn Leaf Plaza'}},
#  '57': {'First Name': 'Gene',
#   'Last Name': 'Vittet',
#   'Email': 'gvittet1k@abc.net.au',
#   'SSN': '768-16-1746',
#   'Address': '26692 Sage Junction',
#   'CID': '86-8652269',
#   'Teacher': {'ID': '52-2884288',
#    'First Name': 'Pancho',
#    'Last Name': 'Dearnley',
#    'Email': 'pdearnley6@google.com.hk',
#    'SSN': '718-13-6984',
#    'Address': '36 Portage Road'}},
#  '58': {'First Name': 'Phillipp',
#   'Last Name': 'Skeeles',
#   'Email': 'pskeeles1l@cocolog-nifty.com',
#   'SSN': '110-27-1223',
#   'Address': '5 David Avenue',
#   'CID': '76-2796204',
#   'Teacher': {'ID': '31-0093154',
#    'First Name': 'Tallie',
#    'Last Name': 'Folker',
#    'Email': 'tfolker7@ftc.gov',
#    'SSN': '674-01-4183',
#    'Address': '438 Tony Road'}},
#  '59': {'First Name': 'Walt',
#   'Last Name': 'Earengey',
#   'Email': 'wearengey1m@ox.ac.uk',
#   'SSN': '322-81-5563',
#   'Address': '74745 Dapin Junction',
#   'CID': '02-4026245',
#   'Teacher': {'ID': '38-5781049',
#    'First Name': 'Elsa',
#    'Last Name': 'Corps',
#    'Email': 'ecorps8@aboutads.info',
#    'SSN': '490-18-7796',
#    'Address': '706 Garrison Lane'}},
#  '60': {'First Name': 'Gar',
#   'Last Name': 'Ortell',
#   'Email': 'gortell1n@ucsd.edu',
#   'SSN': '385-15-1760',
#   'Address': '89 Waubesa Pass',
#   'CID': '52-0676084',
#   'Teacher': {'ID': '58-8777255',
#    'First Name': 'Tracey',
#    'Last Name': 'Scoyles',
#    'Email': 'tscoyles9@biblegateway.com',
#    'SSN': '612-85-3002',
#    'Address': '7 Kennedy Junction'}},
#  '61': {'First Name': 'Dannye',
#   'Last Name': 'Oyley',
#   'Email': 'doyley1o@xing.com',
#   'SSN': '762-18-1799',
#   'Address': '00623 Oak Hill',
#   'CID': '08-2046381',
#   'Teacher': {'ID': '51-3016916',
#    'First Name': 'Jessa',
#    'Last Name': 'Gibbs',
#    'Email': 'jgibbs0@bandcamp.com',
#    'SSN': '733-04-9225',
#    'Address': '32 Ridgeview Circle'}},
#  '62': {'First Name': 'Andrey',
#   'Last Name': 'Tutchener',
#   'Email': 'atutchener1p@ifeng.com',
#   'SSN': '323-58-3405',
#   'Address': '6451 Graceland Crossing',
#   'CID': '57-9105495',
#   'Teacher': {'ID': '03-1224783',
#    'First Name': 'Tate',
#    'Last Name': 'Weekley',
#    'Email': 'tweekley1@nps.gov',
#    'SSN': '392-55-5726',
#    'Address': '5 Lawn Alley'}},
#  '63': {'First Name': 'Scotty',
#   'Last Name': 'Zannini',
#   'Email': 'szannini1q@51.la',
#   'SSN': '196-49-9320',
#   'Address': '11432 Pawling Road',
#   'CID': '76-3364242',
#   'Teacher': {'ID': '33-3280005',
#    'First Name': 'Trenna',
#    'Last Name': 'Chasney',
#    'Email': 'tchasney2@vimeo.com',
#    'SSN': '608-97-4356',
#    'Address': '4 Sunbrook Crossing'}},
#  '64': {'First Name': 'Fredek',
#   'Last Name': 'Denekamp',
#   'Email': 'fdenekamp1r@jiathis.com',
#   'SSN': '898-40-0110',
#   'Address': '29 Portage Parkway',
#   'CID': '32-3782498',
#   'Teacher': {'ID': '19-7014703',
#    'First Name': 'Rabbi',
#    'Last Name': 'McGuinness',
#    'Email': 'rmcguinness3@bloglines.com',
#    'SSN': '548-85-3011',
#    'Address': '12 Sachtjen Street'}},
#  '65': {'First Name': 'Jacquenetta',
#   'Last Name': 'Wilhelmy',
#   'Email': 'jwilhelmy1s@examiner.com',
#   'SSN': '455-56-5310',
#   'Address': '000 East Drive',
#   'CID': '50-4537323',
#   'Teacher': {'ID': '76-7924467',
#    'First Name': 'Amalle',
#    'Last Name': 'Toffetto',
#    'Email': 'atoffetto4@ftc.gov',
#    'SSN': '598-24-7742',
#    'Address': '08 Anzinger Parkway'}},
#  '66': {'First Name': 'Chaim',
#   'Last Name': 'Edmondson',
#   'Email': 'cedmondson1t@tinyurl.com',
#   'SSN': '304-11-0025',
#   'Address': '51 Portage Place',
#   'CID': '83-0287469',
#   'Teacher': {'ID': '99-8422756',
#    'First Name': 'Leilah',
#    'Last Name': 'Parlatt',
#    'Email': 'lparlatt5@about.com',
#    'SSN': '599-97-9346',
#    'Address': '7948 Autumn Leaf Plaza'}},
#  '67': {'First Name': 'Cathy',
#   'Last Name': 'Drew',
#   'Email': 'cdrew1u@amazonaws.com',
#   'SSN': '835-51-2989',
#   'Address': '59 American Way',
#   'CID': '86-8652269',
#   'Teacher': {'ID': '52-2884288',
#    'First Name': 'Pancho',
#    'Last Name': 'Dearnley',
#    'Email': 'pdearnley6@google.com.hk',
#    'SSN': '718-13-6984',
#    'Address': '36 Portage Road'}},
#  '68': {'First Name': 'Kimmie',
#   'Last Name': 'Grimmolby',
#   'Email': 'kgrimmolby1v@tripod.com',
#   'SSN': '669-53-4587',
#   'Address': '2 Granby Trail',
#   'CID': '76-2796204',
#   'Teacher': {'ID': '31-0093154',
#    'First Name': 'Tallie',
#    'Last Name': 'Folker',
#    'Email': 'tfolker7@ftc.gov',
#    'SSN': '674-01-4183',
#    'Address': '438 Tony Road'}},
#  '69': {'First Name': 'Maiga',
#   'Last Name': 'Sebyer',
#   'Email': 'msebyer1w@google.ca',
#   'SSN': '413-79-4378',
#   'Address': '9 Algoma Plaza',
#   'CID': '02-4026245',
#   'Teacher': {'ID': '38-5781049',
#    'First Name': 'Elsa',
#    'Last Name': 'Corps',
#    'Email': 'ecorps8@aboutads.info',
#    'SSN': '490-18-7796',
#    'Address': '706 Garrison Lane'}},
#  '70': {'First Name': 'Blanca',
#   'Last Name': 'Bugbee',
#   'Email': 'bbugbee1x@amazonaws.com',
#   'SSN': '262-40-9833',
#   'Address': '9739 Hallows Trail',
#   'CID': '52-0676084',
#   'Teacher': {'ID': '58-8777255',
#    'First Name': 'Tracey',
#    'Last Name': 'Scoyles',
#    'Email': 'tscoyles9@biblegateway.com',
#    'SSN': '612-85-3002',
#    'Address': '7 Kennedy Junction'}},
#  '71': {'First Name': 'Clemmie',
#   'Last Name': 'Licari',
#   'Email': 'clicari1y@google.fr',
#   'SSN': '234-20-9943',
#   'Address': '9978 South Parkway',
#   'CID': '08-2046381',
#   'Teacher': {'ID': '51-3016916',
#    'First Name': 'Jessa',
#    'Last Name': 'Gibbs',
#    'Email': 'jgibbs0@bandcamp.com',
#    'SSN': '733-04-9225',
#    'Address': '32 Ridgeview Circle'}},
#  '72': {'First Name': 'Ivan',
#   'Last Name': 'Poe',
#   'Email': 'ipoe1z@rambler.ru',
#   'SSN': '610-66-2533',
#   'Address': '48828 Stuart Parkway',
#   'CID': '57-9105495',
#   'Teacher': {'ID': '03-1224783',
#    'First Name': 'Tate',
#    'Last Name': 'Weekley',
#    'Email': 'tweekley1@nps.gov',
#    'SSN': '392-55-5726',
#    'Address': '5 Lawn Alley'}},
#  '73': {'First Name': 'Rhonda',
#   'Last Name': 'Shimony',
#   'Email': 'rshimony20@netlog.com',
#   'SSN': '262-40-7678',
#   'Address': '7811 Esker Place',
#   'CID': '76-3364242',
#   'Teacher': {'ID': '33-3280005',
#    'First Name': 'Trenna',
#    'Last Name': 'Chasney',
#    'Email': 'tchasney2@vimeo.com',
#    'SSN': '608-97-4356',
#    'Address': '4 Sunbrook Crossing'}},
#  '74': {'First Name': 'Leon',
#   'Last Name': 'Rosenbarg',
#   'Email': 'lrosenbarg21@bloglovin.com',
#   'SSN': '291-16-2679',
#   'Address': '61696 Crest Line Trail',
#   'CID': '32-3782498',
#   'Teacher': {'ID': '19-7014703',
#    'First Name': 'Rabbi',
#    'Last Name': 'McGuinness',
#    'Email': 'rmcguinness3@bloglines.com',
#    'SSN': '548-85-3011',
#    'Address': '12 Sachtjen Street'}},
#  '75': {'First Name': 'Lorne',
#   'Last Name': 'Hannant',
#   'Email': 'lhannant22@parallels.com',
#   'SSN': '689-39-9702',
#   'Address': '3535 Sutteridge Drive',
#   'CID': '50-4537323',
#   'Teacher': {'ID': '76-7924467',
#    'First Name': 'Amalle',
#    'Last Name': 'Toffetto',
#    'Email': 'atoffetto4@ftc.gov',
#    'SSN': '598-24-7742',
#    'Address': '08 Anzinger Parkway'}},
#  '76': {'First Name': 'Moina',
#   'Last Name': 'Hemstead',
#   'Email': 'mhemstead23@scientificamerican.com',
#   'SSN': '256-68-5082',
#   'Address': '0 North Center',
#   'CID': '83-0287469',
#   'Teacher': {'ID': '99-8422756',
#    'First Name': 'Leilah',
#    'Last Name': 'Parlatt',
#    'Email': 'lparlatt5@about.com',
#    'SSN': '599-97-9346',
#    'Address': '7948 Autumn Leaf Plaza'}},
#  '77': {'First Name': 'Alberto',
#   'Last Name': 'Spinnace',
#   'Email': 'aspinnace24@slate.com',
#   'SSN': '128-17-9523',
#   'Address': '825 Melrose Street',
#   'CID': '86-8652269',
#   'Teacher': {'ID': '52-2884288',
#    'First Name': 'Pancho',
#    'Last Name': 'Dearnley',
#    'Email': 'pdearnley6@google.com.hk',
#    'SSN': '718-13-6984',
#    'Address': '36 Portage Road'}},
#  '78': {'First Name': 'Krissy',
#   'Last Name': 'Mullinger',
#   'Email': 'kmullinger25@berkeley.edu',
#   'SSN': '200-34-4243',
#   'Address': '3 Forest Run Plaza',
#   'CID': '76-2796204',
#   'Teacher': {'ID': '31-0093154',
#    'First Name': 'Tallie',
#    'Last Name': 'Folker',
#    'Email': 'tfolker7@ftc.gov',
#    'SSN': '674-01-4183',
#    'Address': '438 Tony Road'}},
#  '79': {'First Name': 'Augie',
#   'Last Name': 'Martelet',
#   'Email': 'amartelet26@phoca.cz',
#   'SSN': '368-21-8032',
#   'Address': '76 Northfield Terrace',
#   'CID': '02-4026245',
#   'Teacher': {'ID': '38-5781049',
#    'First Name': 'Elsa',
#    'Last Name': 'Corps',
#    'Email': 'ecorps8@aboutads.info',
#    'SSN': '490-18-7796',
#    'Address': '706 Garrison Lane'}},
#  '80': {'First Name': 'Valentine',
#   'Last Name': 'Fontanet',
#   'Email': 'vfontanet27@dailymail.co.uk',
#   'SSN': '214-06-4833',
#   'Address': '22 Anthes Park',
#   'CID': '52-0676084',
#   'Teacher': {'ID': '58-8777255',
#    'First Name': 'Tracey',
#    'Last Name': 'Scoyles',
#    'Email': 'tscoyles9@biblegateway.com',
#    'SSN': '612-85-3002',
#    'Address': '7 Kennedy Junction'}},
#  '81': {'First Name': 'Ingelbert',
#   'Last Name': 'Comini',
#   'Email': 'icomini28@dyndns.org',
#   'SSN': '829-75-7868',
#   'Address': '2 Esker Lane',
#   'CID': '08-2046381',
#   'Teacher': {'ID': '51-3016916',
#    'First Name': 'Jessa',
#    'Last Name': 'Gibbs',
#    'Email': 'jgibbs0@bandcamp.com',
#    'SSN': '733-04-9225',
#    'Address': '32 Ridgeview Circle'}},
#  '82': {'First Name': 'Georgia',
#   'Last Name': 'Stanistreet',
#   'Email': 'gstanistreet29@ifeng.com',
#   'SSN': '472-60-8695',
#   'Address': '02 Basil Trail',
#   'CID': '57-9105495',
#   'Teacher': {'ID': '03-1224783',
#    'First Name': 'Tate',
#    'Last Name': 'Weekley',
#    'Email': 'tweekley1@nps.gov',
#    'SSN': '392-55-5726',
#    'Address': '5 Lawn Alley'}},
#  '83': {'First Name': 'Ruddy',
#   'Last Name': 'Langelaan',
#   'Email': 'rlangelaan2a@tinyurl.com',
#   'SSN': '860-77-4203',
#   'Address': '7 Crescent Oaks Park',
#   'CID': '76-3364242',
#   'Teacher': {'ID': '33-3280005',
#    'First Name': 'Trenna',
#    'Last Name': 'Chasney',
#    'Email': 'tchasney2@vimeo.com',
#    'SSN': '608-97-4356',
#    'Address': '4 Sunbrook Crossing'}},
#  '84': {'First Name': 'Efren',
#   'Last Name': 'Balstone',
#   'Email': 'ebalstone2b@tuttocitta.it',
#   'SSN': '275-29-4314',
#   'Address': '25638 Loeprich Street',
#   'CID': '32-3782498',
#   'Teacher': {'ID': '19-7014703',
#    'First Name': 'Rabbi',
#    'Last Name': 'McGuinness',
#    'Email': 'rmcguinness3@bloglines.com',
#    'SSN': '548-85-3011',
#    'Address': '12 Sachtjen Street'}},
#  '85': {'First Name': 'Leonerd',
#   'Last Name': 'Beelby',
#   'Email': 'lbeelby2c@cloudflare.com',
#   'SSN': '303-01-4225',
#   'Address': '9367 Sycamore Lane',
#   'CID': '50-4537323',
#   'Teacher': {'ID': '76-7924467',
#    'First Name': 'Amalle',
#    'Last Name': 'Toffetto',
#    'Email': 'atoffetto4@ftc.gov',
#    'SSN': '598-24-7742',
#    'Address': '08 Anzinger Parkway'}},
#  '86': {'First Name': 'Ossie',
#   'Last Name': 'Cleaton',
#   'Email': 'ocleaton2d@e-recht24.de',
#   'SSN': '776-41-8283',
#   'Address': '657 Gerald Hill',
#   'CID': '83-0287469',
#   'Teacher': {'ID': '99-8422756',
#    'First Name': 'Leilah',
#    'Last Name': 'Parlatt',
#    'Email': 'lparlatt5@about.com',
#    'SSN': '599-97-9346',
#    'Address': '7948 Autumn Leaf Plaza'}},
#  '87': {'First Name': 'Ofelia',
#   'Last Name': 'Milson',
#   'Email': 'omilson2e@hostgator.com',
#   'SSN': '869-95-5063',
#   'Address': '5 Delladonna Center',
#   'CID': '86-8652269',
#   'Teacher': {'ID': '52-2884288',
#    'First Name': 'Pancho',
#    'Last Name': 'Dearnley',
#    'Email': 'pdearnley6@google.com.hk',
#    'SSN': '718-13-6984',
#    'Address': '36 Portage Road'}},
#  '88': {'First Name': 'Dora',
#   'Last Name': 'Dakhno',
#   'Email': 'ddakhno2f@wunderground.com',
#   'SSN': '358-96-2359',
#   'Address': '06547 Bashford Road',
#   'CID': '76-2796204',
#   'Teacher': {'ID': '31-0093154',
#    'First Name': 'Tallie',
#    'Last Name': 'Folker',
#    'Email': 'tfolker7@ftc.gov',
#    'SSN': '674-01-4183',
#    'Address': '438 Tony Road'}},
#  '89': {'First Name': 'Timothy',
#   'Last Name': 'Hearty',
#   'Email': 'thearty2g@simplemachines.org',
#   'SSN': '243-80-2382',
#   'Address': '217 Clove Point',
#   'CID': '02-4026245',
#   'Teacher': {'ID': '38-5781049',
#    'First Name': 'Elsa',
#    'Last Name': 'Corps',
#    'Email': 'ecorps8@aboutads.info',
#    'SSN': '490-18-7796',
#    'Address': '706 Garrison Lane'}},
#  '90': {'First Name': 'Matthieu',
#   'Last Name': 'Bridgewater',
#   'Email': 'mbridgewater2h@networkadvertising.org',
#   'SSN': '442-77-7125',
#   'Address': '24 Loomis Road',
#   'CID': '52-0676084',
#   'Teacher': {'ID': '58-8777255',
#    'First Name': 'Tracey',
#    'Last Name': 'Scoyles',
#    'Email': 'tscoyles9@biblegateway.com',
#    'SSN': '612-85-3002',
#    'Address': '7 Kennedy Junction'}},
#  '91': {'First Name': 'Gianina',
#   'Last Name': 'Newbury',
#   'Email': 'gnewbury2i@sun.com',
#   'SSN': '821-94-5016',
#   'Address': '608 Sherman Junction',
#   'CID': '08-2046381',
#   'Teacher': {'ID': '51-3016916',
#    'First Name': 'Jessa',
#    'Last Name': 'Gibbs',
#    'Email': 'jgibbs0@bandcamp.com',
#    'SSN': '733-04-9225',
#    'Address': '32 Ridgeview Circle'}},
#  '92': {'First Name': 'Dredi',
#   'Last Name': 'Harkus',
#   'Email': 'dharkus2j@last.fm',
#   'SSN': '216-90-0477',
#   'Address': '3890 Almo Street',
#   'CID': '57-9105495',
#   'Teacher': {'ID': '03-1224783',
#    'First Name': 'Tate',
#    'Last Name': 'Weekley',
#    'Email': 'tweekley1@nps.gov',
#    'SSN': '392-55-5726',
#    'Address': '5 Lawn Alley'}},
#  '93': {'First Name': 'Tiffie',
#   'Last Name': 'Kingsnod',
#   'Email': 'tkingsnod2k@bloglines.com',
#   'SSN': '561-12-0950',
#   'Address': '83 Ridgeway Court',
#   'CID': '76-3364242',
#   'Teacher': {'ID': '33-3280005',
#    'First Name': 'Trenna',
#    'Last Name': 'Chasney',
#    'Email': 'tchasney2@vimeo.com',
#    'SSN': '608-97-4356',
#    'Address': '4 Sunbrook Crossing'}},
#  '94': {'First Name': 'Addy',
#   'Last Name': 'Russi',
#   'Email': 'arussi2l@gov.uk',
#   'SSN': '682-56-1829',
#   'Address': '8 Havey Circle',
#   'CID': '32-3782498',
#   'Teacher': {'ID': '19-7014703',
#    'First Name': 'Rabbi',
#    'Last Name': 'McGuinness',
#    'Email': 'rmcguinness3@bloglines.com',
#    'SSN': '548-85-3011',
#    'Address': '12 Sachtjen Street'}},
#  '95': {'First Name': 'Rosette',
#   'Last Name': 'Hallums',
#   'Email': 'rhallums2m@rediff.com',
#   'SSN': '211-15-9475',
#   'Address': '849 Anthes Way',
#   'CID': '50-4537323',
#   'Teacher': {'ID': '76-7924467',
#    'First Name': 'Amalle',
#    'Last Name': 'Toffetto',
#    'Email': 'atoffetto4@ftc.gov',
#    'SSN': '598-24-7742',
#    'Address': '08 Anzinger Parkway'}},
#  '96': {'First Name': 'Morlee',
#   'Last Name': 'Mortimer',
#   'Email': 'mmortimer2n@netlog.com',
#   'SSN': '259-37-1266',
#   'Address': '4056 Butterfield Terrace',
#   'CID': '83-0287469',
#   'Teacher': {'ID': '99-8422756',
#    'First Name': 'Leilah',
#    'Last Name': 'Parlatt',
#    'Email': 'lparlatt5@about.com',
#    'SSN': '599-97-9346',
#    'Address': '7948 Autumn Leaf Plaza'}},
#  '97': {'First Name': 'Celeste',
#   'Last Name': 'Gatus',
#   'Email': 'cgatus2o@guardian.co.uk',
#   'SSN': '242-28-9616',
#   'Address': '8 Namekagon Drive',
#   'CID': '86-8652269',
#   'Teacher': {'ID': '52-2884288',
#    'First Name': 'Pancho',
#    'Last Name': 'Dearnley',
#    'Email': 'pdearnley6@google.com.hk',
#    'SSN': '718-13-6984',
#    'Address': '36 Portage Road'}},
#  '98': {'First Name': 'Kaye',
#   'Last Name': 'Metson',
#   'Email': 'kmetson2p@freewebs.com',
#   'SSN': '466-83-3628',
#   'Address': '06530 Petterle Lane',
#   'CID': '76-2796204',
#   'Teacher': {'ID': '31-0093154',
#    'First Name': 'Tallie',
#    'Last Name': 'Folker',
#    'Email': 'tfolker7@ftc.gov',
#    'SSN': '674-01-4183',
#    'Address': '438 Tony Road'}},
#  '99': {'First Name': 'Deane',
#   'Last Name': 'Still',
#   'Email': 'dstill2q@cocolog-nifty.com',
#   'SSN': '356-60-0038',
#   'Address': '052 Kedzie Plaza',
#   'CID': '02-4026245',
#   'Teacher': {'ID': '38-5781049',
#    'First Name': 'Elsa',
#    'Last Name': 'Corps',
#    'Email': 'ecorps8@aboutads.info',
#    'SSN': '490-18-7796',
#    'Address': '706 Garrison Lane'}},
#  '100': {'First Name': 'Emmott',
#   'Last Name': 'Orgee',
#   'Email': 'eorgee2r@reuters.com',
#   'SSN': '880-48-9803',
#   'Address': '20 Myrtle Parkway',
#   'CID': '52-0676084',
#   'Teacher': {'ID': '58-8777255',
#    'First Name': 'Tracey',
#    'Last Name': 'Scoyles',
#    'Email': 'tscoyles9@biblegateway.com',
#    'SSN': '612-85-3002',
#    'Address': '7 Kennedy Junction'}},
#  '101': {'First Name': 'Shaylah',
#   'Last Name': 'Ferres',
#   'Email': 'sferres2s@accuweather.com',
#   'SSN': '221-20-8977',
#   'Address': '648 Fairfield Hill',
#   'CID': '08-2046381',
#   'Teacher': {'ID': '51-3016916',
#    'First Name': 'Jessa',
#    'Last Name': 'Gibbs',
#    'Email': 'jgibbs0@bandcamp.com',
#    'SSN': '733-04-9225',
#    'Address': '32 Ridgeview Circle'}},
#  '102': {'First Name': 'Berti',
#   'Last Name': 'Fishly',
#   'Email': 'bfishly2t@cargocollective.com',
#   'SSN': '271-70-5750',
#   'Address': '0 Superior Court',
#   'CID': '57-9105495',
#   'Teacher': {'ID': '03-1224783',
#    'First Name': 'Tate',
#    'Last Name': 'Weekley',
#    'Email': 'tweekley1@nps.gov',
#    'SSN': '392-55-5726',
#    'Address': '5 Lawn Alley'}},
#  '103': {'First Name': 'Gwennie',
#   'Last Name': 'Rentoll',
#   'Email': 'grentoll2u@geocities.com',
#   'SSN': '574-22-1140',
#   'Address': '0424 Thompson Hill',
#   'CID': '76-3364242',
#   'Teacher': {'ID': '33-3280005',
#    'First Name': 'Trenna',
#    'Last Name': 'Chasney',
#    'Email': 'tchasney2@vimeo.com',
#    'SSN': '608-97-4356',
#    'Address': '4 Sunbrook Crossing'}},
#  '104': {'First Name': 'Debera',
#   'Last Name': 'Sloan',
#   'Email': 'dsloan2v@mapy.cz',
#   'SSN': '430-18-7578',
#   'Address': '1 Scofield Trail',
#   'CID': '32-3782498',
#   'Teacher': {'ID': '19-7014703',
#    'First Name': 'Rabbi',
#    'Last Name': 'McGuinness',
#    'Email': 'rmcguinness3@bloglines.com',
#    'SSN': '548-85-3011',
#    'Address': '12 Sachtjen Street'}},
#  '105': {'First Name': 'Annadiane',
#   'Last Name': 'Naile',
#   'Email': 'anaile2w@about.com',
#   'SSN': '749-89-5466',
#   'Address': '26628 Stuart Road',
#   'CID': '50-4537323',
#   'Teacher': {'ID': '76-7924467',
#    'First Name': 'Amalle',
#    'Last Name': 'Toffetto',
#    'Email': 'atoffetto4@ftc.gov',
#    'SSN': '598-24-7742',
#    'Address': '08 Anzinger Parkway'}},
#  '106': {'First Name': 'Bryanty',
#   'Last Name': 'Coatham',
#   'Email': 'bcoatham2x@mac.com',
#   'SSN': '232-25-3020',
#   'Address': '508 Division Street',
#   'CID': '83-0287469',
#   'Teacher': {'ID': '99-8422756',
#    'First Name': 'Leilah',
#    'Last Name': 'Parlatt',
#    'Email': 'lparlatt5@about.com',
#    'SSN': '599-97-9346',
#    'Address': '7948 Autumn Leaf Plaza'}},
#  '107': {'First Name': 'Marlene',
#   'Last Name': 'Hook',
#   'Email': 'mhook2y@bluehost.com',
#   'SSN': '752-79-0970',
#   'Address': '06935 Lunder Place',
#   'CID': '86-8652269',
#   'Teacher': {'ID': '52-2884288',
#    'First Name': 'Pancho',
#    'Last Name': 'Dearnley',
#    'Email': 'pdearnley6@google.com.hk',
#    'SSN': '718-13-6984',
#    'Address': '36 Portage Road'}},
#  '108': {'First Name': 'Ross',
#   'Last Name': 'Franzonello',
#   'Email': 'rfranzonello2z@tmall.com',
#   'SSN': '421-21-1461',
#   'Address': '3318 Cherokee Circle',
#   'CID': '76-2796204',
#   'Teacher': {'ID': '31-0093154',
#    'First Name': 'Tallie',
#    'Last Name': 'Folker',
#    'Email': 'tfolker7@ftc.gov',
#    'SSN': '674-01-4183',
#    'Address': '438 Tony Road'}},
#  '109': {'First Name': 'Miltie',
#   'Last Name': 'Veazey',
#   'Email': 'mveazey30@vkontakte.ru',
#   'SSN': '676-11-3731',
#   'Address': '7 Corry Court',
#   'CID': '02-4026245',
#   'Teacher': {'ID': '38-5781049',
#    'First Name': 'Elsa',
#    'Last Name': 'Corps',
#    'Email': 'ecorps8@aboutads.info',
#    'SSN': '490-18-7796',
#    'Address': '706 Garrison Lane'}},
#  '110': {'First Name': 'Alberik',
#   'Last Name': 'McTrustey',
#   'Email': 'amctrustey31@whitehouse.gov',
#   'SSN': '109-49-2248',
#   'Address': '58 West Hill',
#   'CID': '52-0676084',
#   'Teacher': {'ID': '58-8777255',
#    'First Name': 'Tracey',
#    'Last Name': 'Scoyles',
#    'Email': 'tscoyles9@biblegateway.com',
#    'SSN': '612-85-3002',
#    'Address': '7 Kennedy Junction'}},
#  '111': {'First Name': 'Quinn',
#   'Last Name': 'Shrimpling',
#   'Email': 'qshrimpling32@ow.ly',
#   'SSN': '695-92-7645',
#   'Address': '138 Mallard Hill',
#   'CID': '08-2046381',
#   'Teacher': {'ID': '51-3016916',
#    'First Name': 'Jessa',
#    'Last Name': 'Gibbs',
#    'Email': 'jgibbs0@bandcamp.com',
#    'SSN': '733-04-9225',
#    'Address': '32 Ridgeview Circle'}},
#  '112': {'First Name': 'Valida',
#   'Last Name': 'Cantle',
#   'Email': 'vcantle33@hostgator.com',
#   'SSN': '755-63-0242',
#   'Address': '4 Northwestern Street',
#   'CID': '57-9105495',
#   'Teacher': {'ID': '03-1224783',
#    'First Name': 'Tate',
#    'Last Name': 'Weekley',
#    'Email': 'tweekley1@nps.gov',
#    'SSN': '392-55-5726',
#    'Address': '5 Lawn Alley'}},
#  '113': {'First Name': 'Carolin',
#   'Last Name': 'Ossipenko',
#   'Email': 'cossipenko34@drupal.org',
#   'SSN': '352-23-4021',
#   'Address': '3167 Thackeray Point',
#   'CID': '76-3364242',
#   'Teacher': {'ID': '33-3280005',
#    'First Name': 'Trenna',
#    'Last Name': 'Chasney',
#    'Email': 'tchasney2@vimeo.com',
#    'SSN': '608-97-4356',
#    'Address': '4 Sunbrook Crossing'}},
#  '114': {'First Name': 'Vic',
#   'Last Name': 'Edgars',
#   'Email': 'vedgars35@mtv.com',
#   'SSN': '572-91-1546',
#   'Address': '996 Rockefeller Pass',
#   'CID': '32-3782498',
#   'Teacher': {'ID': '19-7014703',
#    'First Name': 'Rabbi',
#    'Last Name': 'McGuinness',
#    'Email': 'rmcguinness3@bloglines.com',
#    'SSN': '548-85-3011',
#    'Address': '12 Sachtjen Street'}},
#  '115': {'First Name': 'Frasquito',
#   'Last Name': 'Bygott',
#   'Email': 'fbygott36@ow.ly',
#   'SSN': '266-75-1154',
#   'Address': '4034 Mayer Circle',
#   'CID': '50-4537323',
#   'Teacher': {'ID': '76-7924467',
#    'First Name': 'Amalle',
#    'Last Name': 'Toffetto',
#    'Email': 'atoffetto4@ftc.gov',
#    'SSN': '598-24-7742',
#    'Address': '08 Anzinger Parkway'}},
#  '116': {'First Name': 'Klement',
#   'Last Name': 'Arnaud',
#   'Email': 'karnaud37@shutterfly.com',
#   'SSN': '611-12-7059',
#   'Address': '8 Steensland Drive',
#   'CID': '83-0287469',
#   'Teacher': {'ID': '99-8422756',
#    'First Name': 'Leilah',
#    'Last Name': 'Parlatt',
#    'Email': 'lparlatt5@about.com',
#    'SSN': '599-97-9346',
#    'Address': '7948 Autumn Leaf Plaza'}},
#  '117': {'First Name': 'Ezequiel',
#   'Last Name': 'Pitfield',
#   'Email': 'epitfield38@psu.edu',
#   'SSN': '376-02-7794',
#   'Address': '9 Morrow Park',
#   'CID': '86-8652269',
#   'Teacher': {'ID': '52-2884288',
#    'First Name': 'Pancho',
#    'Last Name': 'Dearnley',
#    'Email': 'pdearnley6@google.com.hk',
#    'SSN': '718-13-6984',
#    'Address': '36 Portage Road'}},
#  '118': {'First Name': 'Loree',
#   'Last Name': 'Philpots',
#   'Email': 'lphilpots39@apache.org',
#   'SSN': '530-21-4535',
#   'Address': '7 Roxbury Point',
#   'CID': '76-2796204',
#   'Teacher': {'ID': '31-0093154',
#    'First Name': 'Tallie',
#    'Last Name': 'Folker',
#    'Email': 'tfolker7@ftc.gov',
#    'SSN': '674-01-4183',
#    'Address': '438 Tony Road'}},
#  '119': {'First Name': 'Angy',
#   'Last Name': 'Meckiff',
#   'Email': 'ameckiff3a@opera.com',
#   'SSN': '748-45-4887',
#   'Address': '0600 Schlimgen Park',
#   'CID': '02-4026245',
#   'Teacher': {'ID': '38-5781049',
#    'First Name': 'Elsa',
#    'Last Name': 'Corps',
#    'Email': 'ecorps8@aboutads.info',
#    'SSN': '490-18-7796',
#    'Address': '706 Garrison Lane'}},
#  '120': {'First Name': 'Tressa',
#   'Last Name': 'Etock',
#   'Email': 'tetock3b@noaa.gov',
#   'SSN': '770-24-4541',
#   'Address': '0750 Grasskamp Circle',
#   'CID': '52-0676084',
#   'Teacher': {'ID': '58-8777255',
#    'First Name': 'Tracey',
#    'Last Name': 'Scoyles',
#    'Email': 'tscoyles9@biblegateway.com',
#    'SSN': '612-85-3002',
#    'Address': '7 Kennedy Junction'}},
#  '121': {'First Name': 'Blondell',
#   'Last Name': 'Witham',
#   'Email': 'bwitham3c@elegantthemes.com',
#   'SSN': '752-19-8858',
#   'Address': '73 Susan Center',
#   'CID': '08-2046381',
#   'Teacher': {'ID': '51-3016916',
#    'First Name': 'Jessa',
#    'Last Name': 'Gibbs',
#    'Email': 'jgibbs0@bandcamp.com',
#    'SSN': '733-04-9225',
#    'Address': '32 Ridgeview Circle'}},
#  '122': {'First Name': 'Jess',
#   'Last Name': 'Klazenga',
#   'Email': 'jklazenga3d@dagondesign.com',
#   'SSN': '557-38-9104',
#   'Address': '6 Hauk Trail',
#   'CID': '57-9105495',
#   'Teacher': {'ID': '03-1224783',
#    'First Name': 'Tate',
#    'Last Name': 'Weekley',
#    'Email': 'tweekley1@nps.gov',
#    'SSN': '392-55-5726',
#    'Address': '5 Lawn Alley'}},
#  '123': {'First Name': 'Lynelle',
#   'Last Name': 'Ghelardi',
#   'Email': 'lghelardi3e@angelfire.com',
#   'SSN': '740-45-0013',
#   'Address': '3627 Meadow Vale Park',
#   'CID': '76-3364242',
#   'Teacher': {'ID': '33-3280005',
#    'First Name': 'Trenna',
#    'Last Name': 'Chasney',
#    'Email': 'tchasney2@vimeo.com',
#    'SSN': '608-97-4356',
#    'Address': '4 Sunbrook Crossing'}},
#  '124': {'First Name': 'Carolyn',
#   'Last Name': 'Lowrie',
#   'Email': 'clowrie3f@sphinn.com',
#   'SSN': '596-29-6930',
#   'Address': '354 Meadow Ridge Drive',
#   'CID': '32-3782498',
#   'Teacher': {'ID': '19-7014703',
#    'First Name': 'Rabbi',
#    'Last Name': 'McGuinness',
#    'Email': 'rmcguinness3@bloglines.com',
#    'SSN': '548-85-3011',
#    'Address': '12 Sachtjen Street'}},
#  '125': {'First Name': 'Silvia',
#   'Last Name': 'Mattosoff',
#   'Email': 'smattosoff3g@xrea.com',
#   'SSN': '564-22-4781',
#   'Address': '54 Carpenter Junction',
#   'CID': '50-4537323',
#   'Teacher': {'ID': '76-7924467',
#    'First Name': 'Amalle',
#    'Last Name': 'Toffetto',
#    'Email': 'atoffetto4@ftc.gov',
#    'SSN': '598-24-7742',
#    'Address': '08 Anzinger Parkway'}},
#  '126': {'First Name': 'Carole',
#   'Last Name': 'Bouch',
#   'Email': 'cbouch3h@umn.edu',
#   'SSN': '592-44-7717',
#   'Address': '45 Annamark Center',
#   'CID': '83-0287469',
#   'Teacher': {'ID': '99-8422756',
#    'First Name': 'Leilah',
#    'Last Name': 'Parlatt',
#    'Email': 'lparlatt5@about.com',
#    'SSN': '599-97-9346',
#    'Address': '7948 Autumn Leaf Plaza'}},
#  '127': {'First Name': 'Bertrand',
#   'Last Name': 'Gehring',
#   'Email': 'bgehring3i@disqus.com',
#   'SSN': '635-55-0580',
#   'Address': '85618 Valley Edge Road',
#   'CID': '86-8652269',
#   'Teacher': {'ID': '52-2884288',
#    'First Name': 'Pancho',
#    'Last Name': 'Dearnley',
#    'Email': 'pdearnley6@google.com.hk',
#    'SSN': '718-13-6984',
#    'Address': '36 Portage Road'}},
#  '128': {'First Name': 'Maddy',
#   'Last Name': 'Bowdidge',
#   'Email': 'mbowdidge3j@rediff.com',
#   'SSN': '480-06-5353',
#   'Address': '250 Ridgeway Plaza',
#   'CID': '76-2796204',
#   'Teacher': {'ID': '31-0093154',
#    'First Name': 'Tallie',
#    'Last Name': 'Folker',
#    'Email': 'tfolker7@ftc.gov',
#    'SSN': '674-01-4183',
#    'Address': '438 Tony Road'}},
#  '129': {'First Name': 'Derry',
#   'Last Name': 'Bolland',
#   'Email': 'dbolland3k@soundcloud.com',
#   'SSN': '565-09-8037',
#   'Address': '6 Meadow Valley Lane',
#   'CID': '02-4026245',
#   'Teacher': {'ID': '38-5781049',
#    'First Name': 'Elsa',
#    'Last Name': 'Corps',
#    'Email': 'ecorps8@aboutads.info',
#    'SSN': '490-18-7796',
#    'Address': '706 Garrison Lane'}},
#  '130': {'First Name': 'Cobb',
#   'Last Name': 'Glazier',
#   'Email': 'cglazier3l@usda.gov',
#   'SSN': '784-58-9771',
#   'Address': '6668 Lillian Court',
#   'CID': '52-0676084',
#   'Teacher': {'ID': '58-8777255',
#    'First Name': 'Tracey',
#    'Last Name': 'Scoyles',
#    'Email': 'tscoyles9@biblegateway.com',
#    'SSN': '612-85-3002',
#    'Address': '7 Kennedy Junction'}},
#  '131': {'First Name': 'Lewes',
#   'Last Name': 'Trill',
#   'Email': 'ltrill3m@163.com',
#   'SSN': '109-11-2906',
#   'Address': '4 Forest Lane',
#   'CID': '08-2046381',
#   'Teacher': {'ID': '51-3016916',
#    'First Name': 'Jessa',
#    'Last Name': 'Gibbs',
#    'Email': 'jgibbs0@bandcamp.com',
#    'SSN': '733-04-9225',
#    'Address': '32 Ridgeview Circle'}},
#  '132': {'First Name': 'Anastasie',
#   'Last Name': 'Carles',
#   'Email': 'acarles3n@sciencedaily.com',
#   'SSN': '817-89-6599',
#   'Address': '31 Summerview Alley',
#   'CID': '57-9105495',
#   'Teacher': {'ID': '03-1224783',
#    'First Name': 'Tate',
#    'Last Name': 'Weekley',
#    'Email': 'tweekley1@nps.gov',
#    'SSN': '392-55-5726',
#    'Address': '5 Lawn Alley'}},
#  '133': {'First Name': 'Katerina',
#   'Last Name': 'Edkins',
#   'Email': 'kedkins3o@msn.com',
#   'SSN': '161-31-6584',
# ...
#   'Last Name': 'Edelmann',
#   'Email': 'dedelmannqk@foxnews.com',
#   'SSN': '868-71-8446',
#   'Address': '78 Dovetail Plaza',
#   'CID': '86-8652269',
#   'Teacher': {'ID': '52-2884288',
#    'First Name': 'Pancho',
#    'Last Name': 'Dearnley',
#    'Email': 'pdearnley6@google.com.hk',
#    'SSN': '718-13-6984',
#    'Address': '36 Portage Road'}},
#  '958': {'First Name': 'Miller',
#   'Last Name': 'Brothers',
#   'Email': 'mbrothersql@elpais.com',
#   'SSN': '563-51-6698',
#   'Address': '0 Florence Parkway',
#   'CID': '76-2796204',
#   'Teacher': {'ID': '31-0093154',
#    'First Name': 'Tallie',
#    'Last Name': 'Folker',
#    'Email': 'tfolker7@ftc.gov',
#    'SSN': '674-01-4183',
#    'Address': '438 Tony Road'}},
#  '959': {'First Name': 'Titos',
#   'Last Name': 'Pawlyn',
#   'Email': 'tpawlynqm@nature.com',
#   'SSN': '867-63-5326',
#   'Address': '2700 Dennis Way',
#   'CID': '02-4026245',
#   'Teacher': {'ID': '38-5781049',
#    'First Name': 'Elsa',
#    'Last Name': 'Corps',
#    'Email': 'ecorps8@aboutads.info',
#    'SSN': '490-18-7796',
#    'Address': '706 Garrison Lane'}},
#  '960': {'First Name': 'Steffen',
#   'Last Name': 'Cochern',
#   'Email': 'scochernqn@goo.ne.jp',
#   'SSN': '846-78-6678',
#   'Address': '66 Caliangt Hill',
#   'CID': '52-0676084',
#   'Teacher': {'ID': '58-8777255',
#    'First Name': 'Tracey',
#    'Last Name': 'Scoyles',
#    'Email': 'tscoyles9@biblegateway.com',
#    'SSN': '612-85-3002',
#    'Address': '7 Kennedy Junction'}},
#  '961': {'First Name': 'Kriste',
#   'Last Name': 'Goodge',
#   'Email': 'kgoodgeqo@admin.ch',
#   'SSN': '369-91-7683',
#   'Address': '0750 Hayes Terrace',
#   'CID': '08-2046381',
#   'Teacher': {'ID': '51-3016916',
#    'First Name': 'Jessa',
#    'Last Name': 'Gibbs',
#    'Email': 'jgibbs0@bandcamp.com',
#    'SSN': '733-04-9225',
#    'Address': '32 Ridgeview Circle'}},
#  '962': {'First Name': 'Martino',
#   'Last Name': 'Hasson',
#   'Email': 'mhassonqp@usnews.com',
#   'SSN': '727-49-0204',
#   'Address': '010 Reinke Road',
#   'CID': '57-9105495',
#   'Teacher': {'ID': '03-1224783',
#    'First Name': 'Tate',
#    'Last Name': 'Weekley',
#    'Email': 'tweekley1@nps.gov',
#    'SSN': '392-55-5726',
#    'Address': '5 Lawn Alley'}},
#  '963': {'First Name': 'Antonietta',
#   'Last Name': 'Taffarello',
#   'Email': 'ataffarelloqq@howstuffworks.com',
#   'SSN': '473-17-6073',
#   'Address': '732 Porter Junction',
#   'CID': '76-3364242',
#   'Teacher': {'ID': '33-3280005',
#    'First Name': 'Trenna',
#    'Last Name': 'Chasney',
#    'Email': 'tchasney2@vimeo.com',
#    'SSN': '608-97-4356',
#    'Address': '4 Sunbrook Crossing'}},
#  '964': {'First Name': 'Natty',
#   'Last Name': 'MacSkeagan',
#   'Email': 'nmacskeaganqr@ibm.com',
#   'SSN': '842-20-6955',
#   'Address': '7415 American Circle',
#   'CID': '32-3782498',
#   'Teacher': {'ID': '19-7014703',
#    'First Name': 'Rabbi',
#    'Last Name': 'McGuinness',
#    'Email': 'rmcguinness3@bloglines.com',
#    'SSN': '548-85-3011',
#    'Address': '12 Sachtjen Street'}},
#  '965': {'First Name': 'Hasheem',
#   'Last Name': 'Renshall',
#   'Email': 'hrenshallqs@yellowpages.com',
#   'SSN': '126-46-4512',
#   'Address': '2894 4th Drive',
#   'CID': '50-4537323',
#   'Teacher': {'ID': '76-7924467',
#    'First Name': 'Amalle',
#    'Last Name': 'Toffetto',
#    'Email': 'atoffetto4@ftc.gov',
#    'SSN': '598-24-7742',
#    'Address': '08 Anzinger Parkway'}},
#  '966': {'First Name': 'Jacquette',
#   'Last Name': 'Triggle',
#   'Email': 'jtriggleqt@flickr.com',
#   'SSN': '768-39-1263',
#   'Address': '84 Nevada Hill',
#   'CID': '83-0287469',
#   'Teacher': {'ID': '99-8422756',
#    'First Name': 'Leilah',
#    'Last Name': 'Parlatt',
#    'Email': 'lparlatt5@about.com',
#    'SSN': '599-97-9346',
#    'Address': '7948 Autumn Leaf Plaza'}},
#  '967': {'First Name': 'Lishe',
#   'Last Name': 'Pudney',
#   'Email': 'lpudneyqu@buzzfeed.com',
#   'SSN': '832-65-7433',
#   'Address': '7979 Erie Street',
#   'CID': '86-8652269',
#   'Teacher': {'ID': '52-2884288',
#    'First Name': 'Pancho',
#    'Last Name': 'Dearnley',
#    'Email': 'pdearnley6@google.com.hk',
#    'SSN': '718-13-6984',
#    'Address': '36 Portage Road'}},
#  '968': {'First Name': 'Lissy',
#   'Last Name': 'Hargate',
#   'Email': 'lhargateqv@google.es',
#   'SSN': '744-67-0002',
#   'Address': '5979 South Street',
#   'CID': '76-2796204',
#   'Teacher': {'ID': '31-0093154',
#    'First Name': 'Tallie',
#    'Last Name': 'Folker',
#    'Email': 'tfolker7@ftc.gov',
#    'SSN': '674-01-4183',
#    'Address': '438 Tony Road'}},
#  '969': {'First Name': 'Julia',
#   'Last Name': 'Dowrey',
#   'Email': 'jdowreyqw@google.com.br',
#   'SSN': '481-60-9269',
#   'Address': '6878 Ridgeview Crossing',
#   'CID': '02-4026245',
#   'Teacher': {'ID': '38-5781049',
#    'First Name': 'Elsa',
#    'Last Name': 'Corps',
#    'Email': 'ecorps8@aboutads.info',
#    'SSN': '490-18-7796',
#    'Address': '706 Garrison Lane'}},
#  '970': {'First Name': 'Dana',
#   'Last Name': 'Oxshott',
#   'Email': 'doxshottqx@indiatimes.com',
#   'SSN': '285-29-9311',
#   'Address': '1 Lindbergh Drive',
#   'CID': '52-0676084',
#   'Teacher': {'ID': '58-8777255',
#    'First Name': 'Tracey',
#    'Last Name': 'Scoyles',
#    'Email': 'tscoyles9@biblegateway.com',
#    'SSN': '612-85-3002',
#    'Address': '7 Kennedy Junction'}},
#  '971': {'First Name': 'Chevy',
#   'Last Name': 'Baverstock',
#   'Email': 'cbaverstockqy@omniture.com',
#   'SSN': '800-31-0838',
#   'Address': '0 Welch Parkway',
#   'CID': '08-2046381',
#   'Teacher': {'ID': '51-3016916',
#    'First Name': 'Jessa',
#    'Last Name': 'Gibbs',
#    'Email': 'jgibbs0@bandcamp.com',
#    'SSN': '733-04-9225',
#    'Address': '32 Ridgeview Circle'}},
#  '972': {'First Name': 'Flossy',
#   'Last Name': 'Skirrow',
#   'Email': 'fskirrowqz@archive.org',
#   'SSN': '553-38-7492',
#   'Address': '87401 Graedel Circle',
#   'CID': '57-9105495',
#   'Teacher': {'ID': '03-1224783',
#    'First Name': 'Tate',
#    'Last Name': 'Weekley',
#    'Email': 'tweekley1@nps.gov',
#    'SSN': '392-55-5726',
#    'Address': '5 Lawn Alley'}},
#  '973': {'First Name': 'Angil',
#   'Last Name': 'Dietmar',
#   'Email': 'adietmarr0@rakuten.co.jp',
#   'SSN': '174-07-4915',
#   'Address': '24535 Homewood Way',
#   'CID': '76-3364242',
#   'Teacher': {'ID': '33-3280005',
#    'First Name': 'Trenna',
#    'Last Name': 'Chasney',
#    'Email': 'tchasney2@vimeo.com',
#    'SSN': '608-97-4356',
#    'Address': '4 Sunbrook Crossing'}},
#  '974': {'First Name': 'Waite',
#   'Last Name': 'Whiteman',
#   'Email': 'wwhitemanr1@bizjournals.com',
#   'SSN': '446-79-0069',
#   'Address': '8465 Pawling Alley',
#   'CID': '32-3782498',
#   'Teacher': {'ID': '19-7014703',
#    'First Name': 'Rabbi',
#    'Last Name': 'McGuinness',
#    'Email': 'rmcguinness3@bloglines.com',
#    'SSN': '548-85-3011',
#    'Address': '12 Sachtjen Street'}},
#  '975': {'First Name': 'Geordie',
#   'Last Name': 'Tiffin',
#   'Email': 'gtiffinr2@elpais.com',
#   'SSN': '647-38-0447',
#   'Address': '9933 Colorado Drive',
#   'CID': '50-4537323',
#   'Teacher': {'ID': '76-7924467',
#    'First Name': 'Amalle',
#    'Last Name': 'Toffetto',
#    'Email': 'atoffetto4@ftc.gov',
#    'SSN': '598-24-7742',
#    'Address': '08 Anzinger Parkway'}},
#  '976': {'First Name': 'Datha',
#   'Last Name': 'Pirrone',
#   'Email': 'dpirroner3@so-net.ne.jp',
#   'SSN': '422-65-9057',
#   'Address': '1027 Dixon Junction',
#   'CID': '83-0287469',
#   'Teacher': {'ID': '99-8422756',
#    'First Name': 'Leilah',
#    'Last Name': 'Parlatt',
#    'Email': 'lparlatt5@about.com',
#    'SSN': '599-97-9346',
#    'Address': '7948 Autumn Leaf Plaza'}},
#  '977': {'First Name': 'Zebedee',
#   'Last Name': 'Bearward',
#   'Email': 'zbearwardr4@opera.com',
#   'SSN': '845-80-5111',
#   'Address': '0 Lukken Plaza',
#   'CID': '86-8652269',
#   'Teacher': {'ID': '52-2884288',
#    'First Name': 'Pancho',
#    'Last Name': 'Dearnley',
#    'Email': 'pdearnley6@google.com.hk',
#    'SSN': '718-13-6984',
#    'Address': '36 Portage Road'}},
#  '978': {'First Name': 'Jessica',
#   'Last Name': 'Veel',
#   'Email': 'jveelr5@facebook.com',
#   'SSN': '284-47-0722',
#   'Address': '08965 Lukken Trail',
#   'CID': '76-2796204',
#   'Teacher': {'ID': '31-0093154',
#    'First Name': 'Tallie',
#    'Last Name': 'Folker',
#    'Email': 'tfolker7@ftc.gov',
#    'SSN': '674-01-4183',
#    'Address': '438 Tony Road'}},
#  '979': {'First Name': 'Fowler',
#   'Last Name': 'Anyon',
#   'Email': 'fanyonr6@patch.com',
#   'SSN': '330-56-2797',
#   'Address': '9 Marquette Pass',
#   'CID': '02-4026245',
#   'Teacher': {'ID': '38-5781049',
#    'First Name': 'Elsa',
#    'Last Name': 'Corps',
#    'Email': 'ecorps8@aboutads.info',
#    'SSN': '490-18-7796',
#    'Address': '706 Garrison Lane'}},
#  '980': {'First Name': 'Ellswerth',
#   'Last Name': 'Poplee',
#   'Email': 'epopleer7@issuu.com',
#   'SSN': '310-73-6816',
#   'Address': '714 Logan Plaza',
#   'CID': '52-0676084',
#   'Teacher': {'ID': '58-8777255',
#    'First Name': 'Tracey',
#    'Last Name': 'Scoyles',
#    'Email': 'tscoyles9@biblegateway.com',
#    'SSN': '612-85-3002',
#    'Address': '7 Kennedy Junction'}},
#  '981': {'First Name': 'Nahum',
#   'Last Name': 'McCrackan',
#   'Email': 'nmccrackanr8@theglobeandmail.com',
#   'SSN': '322-33-5426',
#   'Address': '76 Calypso Alley',
#   'CID': '08-2046381',
#   'Teacher': {'ID': '51-3016916',
#    'First Name': 'Jessa',
#    'Last Name': 'Gibbs',
#    'Email': 'jgibbs0@bandcamp.com',
#    'SSN': '733-04-9225',
#    'Address': '32 Ridgeview Circle'}},
#  '982': {'First Name': 'Thoma',
#   'Last Name': 'Alenov',
#   'Email': 'talenovr9@disqus.com',
#   'SSN': '722-26-1226',
#   'Address': '68 Prairie Rose Pass',
#   'CID': '57-9105495',
#   'Teacher': {'ID': '03-1224783',
#    'First Name': 'Tate',
#    'Last Name': 'Weekley',
#    'Email': 'tweekley1@nps.gov',
#    'SSN': '392-55-5726',
#    'Address': '5 Lawn Alley'}},
#  '983': {'First Name': 'Clarissa',
#   'Last Name': 'Philpault',
#   'Email': 'cphilpaultra@epa.gov',
#   'SSN': '293-52-4512',
#   'Address': '343 Brickson Park Drive',
#   'CID': '76-3364242',
#   'Teacher': {'ID': '33-3280005',
#    'First Name': 'Trenna',
#    'Last Name': 'Chasney',
#    'Email': 'tchasney2@vimeo.com',
#    'SSN': '608-97-4356',
#    'Address': '4 Sunbrook Crossing'}},
#  '984': {'First Name': 'Freddy',
#   'Last Name': 'Gyer',
#   'Email': 'fgyerrb@ocn.ne.jp',
#   'SSN': '726-88-8762',
#   'Address': '72 Nevada Park',
#   'CID': '32-3782498',
#   'Teacher': {'ID': '19-7014703',
#    'First Name': 'Rabbi',
#    'Last Name': 'McGuinness',
#    'Email': 'rmcguinness3@bloglines.com',
#    'SSN': '548-85-3011',
#    'Address': '12 Sachtjen Street'}},
#  '985': {'First Name': 'Tye',
#   'Last Name': 'Steinhammer',
#   'Email': 'tsteinhammerrc@facebook.com',
#   'SSN': '524-15-6291',
#   'Address': '10428 Larry Trail',
#   'CID': '50-4537323',
#   'Teacher': {'ID': '76-7924467',
#    'First Name': 'Amalle',
#    'Last Name': 'Toffetto',
#    'Email': 'atoffetto4@ftc.gov',
#    'SSN': '598-24-7742',
#    'Address': '08 Anzinger Parkway'}},
#  '986': {'First Name': 'Gregorio',
#   'Last Name': 'Reynish',
#   'Email': 'greynishrd@cyberchimps.com',
#   'SSN': '520-27-2960',
#   'Address': '18 Eggendart Point',
#   'CID': '83-0287469',
#   'Teacher': {'ID': '99-8422756',
#    'First Name': 'Leilah',
#    'Last Name': 'Parlatt',
#    'Email': 'lparlatt5@about.com',
#    'SSN': '599-97-9346',
#    'Address': '7948 Autumn Leaf Plaza'}},
#  '987': {'First Name': 'Isabeau',
#   'Last Name': 'Klink',
#   'Email': 'iklinkre@acquirethisname.com',
#   'SSN': '830-27-4473',
#   'Address': '16812 Sutteridge Circle',
#   'CID': '86-8652269',
#   'Teacher': {'ID': '52-2884288',
#    'First Name': 'Pancho',
#    'Last Name': 'Dearnley',
#    'Email': 'pdearnley6@google.com.hk',
#    'SSN': '718-13-6984',
#    'Address': '36 Portage Road'}},
#  '988': {'First Name': 'Phil',
#   'Last Name': 'Munslow',
#   'Email': 'pmunslowrf@pen.io',
#   'SSN': '628-54-3557',
#   'Address': '6189 Grover Terrace',
#   'CID': '76-2796204',
#   'Teacher': {'ID': '31-0093154',
#    'First Name': 'Tallie',
#    'Last Name': 'Folker',
#    'Email': 'tfolker7@ftc.gov',
#    'SSN': '674-01-4183',
#    'Address': '438 Tony Road'}},
#  '989': {'First Name': 'Erica',
#   'Last Name': 'Gabler',
#   'Email': 'egablerrg@123-reg.co.uk',
#   'SSN': '615-20-1882',
#   'Address': '260 1st Lane',
#   'CID': '02-4026245',
#   'Teacher': {'ID': '38-5781049',
#    'First Name': 'Elsa',
#    'Last Name': 'Corps',
#    'Email': 'ecorps8@aboutads.info',
#    'SSN': '490-18-7796',
#    'Address': '706 Garrison Lane'}},
#  '990': {'First Name': 'Rayner',
#   'Last Name': 'Fantin',
#   'Email': 'rfantinrh@aboutads.info',
#   'SSN': '733-48-8091',
#   'Address': '8 Village Hill',
#   'CID': '52-0676084',
#   'Teacher': {'ID': '58-8777255',
#    'First Name': 'Tracey',
#    'Last Name': 'Scoyles',
#    'Email': 'tscoyles9@biblegateway.com',
#    'SSN': '612-85-3002',
#    'Address': '7 Kennedy Junction'}},
#  '991': {'First Name': 'Auroora',
#   'Last Name': 'Ramirez',
#   'Email': 'aramirezri@wordpress.com',
#   'SSN': '598-03-5756',
#   'Address': '2778 Lunder Avenue',
#   'CID': '08-2046381',
#   'Teacher': {'ID': '51-3016916',
#    'First Name': 'Jessa',
#    'Last Name': 'Gibbs',
#    'Email': 'jgibbs0@bandcamp.com',
#    'SSN': '733-04-9225',
#    'Address': '32 Ridgeview Circle'}},
#  '992': {'First Name': 'Amy',
#   'Last Name': "O'Dyvoy",
#   'Email': 'aodyvoyrj@deliciousdays.com',
#   'SSN': '428-66-4740',
#   'Address': '55 Moose Road',
#   'CID': '57-9105495',
#   'Teacher': {'ID': '03-1224783',
#    'First Name': 'Tate',
#    'Last Name': 'Weekley',
#    'Email': 'tweekley1@nps.gov',
#    'SSN': '392-55-5726',
#    'Address': '5 Lawn Alley'}},
#  '993': {'First Name': 'Adrianne',
#   'Last Name': 'Linklater',
#   'Email': 'alinklaterrk@theatlantic.com',
#   'SSN': '832-35-2358',
#   'Address': '757 Prairieview Crossing',
#   'CID': '76-3364242',
#   'Teacher': {'ID': '33-3280005',
#    'First Name': 'Trenna',
#    'Last Name': 'Chasney',
#    'Email': 'tchasney2@vimeo.com',
#    'SSN': '608-97-4356',
#    'Address': '4 Sunbrook Crossing'}},
#  '994': {'First Name': 'Greer',
#   'Last Name': 'Meuse',
#   'Email': 'gmeuserl@earthlink.net',
#   'SSN': '800-17-2330',
#   'Address': '2 Melody Circle',
#   'CID': '32-3782498',
#   'Teacher': {'ID': '19-7014703',
#    'First Name': 'Rabbi',
#    'Last Name': 'McGuinness',
#    'Email': 'rmcguinness3@bloglines.com',
#    'SSN': '548-85-3011',
#    'Address': '12 Sachtjen Street'}},
#  '995': {'First Name': 'Danica',
#   'Last Name': 'Mower',
#   'Email': 'dmowerrm@wisc.edu',
#   'SSN': '129-47-5323',
#   'Address': '739 Bultman Circle',
#   'CID': '50-4537323',
#   'Teacher': {'ID': '76-7924467',
#    'First Name': 'Amalle',
#    'Last Name': 'Toffetto',
#    'Email': 'atoffetto4@ftc.gov',
#    'SSN': '598-24-7742',
#    'Address': '08 Anzinger Parkway'}},
#  '996': {'First Name': 'Edy',
#   'Last Name': 'Dunsford',
#   'Email': 'edunsfordrn@gravatar.com',
#   'SSN': '292-09-6833',
#   'Address': '0 Blackbird Center',
#   'CID': '83-0287469',
#   'Teacher': {'ID': '99-8422756',
#    'First Name': 'Leilah',
#    'Last Name': 'Parlatt',
#    'Email': 'lparlatt5@about.com',
#    'SSN': '599-97-9346',
#    'Address': '7948 Autumn Leaf Plaza'}},
#  '997': {'First Name': 'Karlens',
#   'Last Name': 'Coulsen',
#   'Email': 'kcoulsenro@hp.com',
#   'SSN': '271-05-1263',
#   'Address': '44 Delladonna Lane',
#   'CID': '86-8652269',
#   'Teacher': {'ID': '52-2884288',
#    'First Name': 'Pancho',
#    'Last Name': 'Dearnley',
#    'Email': 'pdearnley6@google.com.hk',
#    'SSN': '718-13-6984',
#    'Address': '36 Portage Road'}},
#  '998': {'First Name': 'Florance',
#   'Last Name': 'Newnham',
#   'Email': 'fnewnhamrp@state.tx.us',
#   'SSN': '760-87-1141',
#   'Address': '739 Bellgrove Lane',
#   'CID': '76-2796204',
#   'Teacher': {'ID': '31-0093154',
#    'First Name': 'Tallie',
#    'Last Name': 'Folker',
#    'Email': 'tfolker7@ftc.gov',
#    'SSN': '674-01-4183',
#    'Address': '438 Tony Road'}},
#  '999': {'First Name': 'Clement',
#   'Last Name': 'Woodham',
#   'Email': 'cwoodhamrq@pbs.org',
#   'SSN': '278-94-6601',
#   'Address': '2192 Walton Road',
#   'CID': '02-4026245',
#   'Teacher': {'ID': '38-5781049',
#    'First Name': 'Elsa',
#    'Last Name': 'Corps',
#    'Email': 'ecorps8@aboutads.info',
#    'SSN': '490-18-7796',
#    'Address': '706 Garrison Lane'}},
#  '1000': {'First Name': 'Taber',
#   'Last Name': 'Schuh',
#   'Email': 'tschuhrr@yellowpages.com',
#   'SSN': '128-44-7095',
#   'Address': '0 Canary Trail',
#   'CID': '52-0676084',
#   'Teacher': {'ID': '58-8777255',
#    'First Name': 'Tracey',
#    'Last Name': 'Scoyles',
#    'Email': 'tscoyles9@biblegateway.com',
#    'SSN': '612-85-3002',
#    'Address': '7 Kennedy Junction'}}}

# %%
pip install docker
# Out:
# Collecting dockerNote: you may need to restart the kernel to use updated packages.
#
#   Downloading docker-5.0.3-py2.py3-none-any.whl (146 kB)
# Collecting websocket-client>=0.32.0
#   Downloading websocket_client-1.3.2-py3-none-any.whl (54 kB)
# Requirement already satisfied: requests!=2.18.0,>=2.14.2 in c:\users\lewis\anaconda3\lib\site-packages (from docker) (2.26.0)
# Collecting pywin32==227
#   Downloading pywin32-227-cp39-cp39-win_amd64.whl (9.1 MB)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\lewis\anaconda3\lib\site-packages (from requests!=2.18.0,>=2.14.2->docker) (1.26.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\lewis\anaconda3\lib\site-packages (from requests!=2.18.0,>=2.14.2->docker) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\lewis\anaconda3\lib\site-packages (from requests!=2.18.0,>=2.14.2->docker) (3.2)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\lewis\anaconda3\lib\site-packages (from requests!=2.18.0,>=2.14.2->docker) (2.0.4)
# Installing collected packages: websocket-client, pywin32, docker
#   Attempting uninstall: pywin32
#     Found existing installation: pywin32 228
#     Uninstalling pywin32-228:
#       Successfully uninstalled pywin32-228
# Successfully installed docker-5.0.3 pywin32-227 websocket-client-1.3.2

# %%
#Containerize using docker
from flask import Flask
server = Flask(__main__)

@server.route("/")
def hello():
    return "Hello World!"

if __name__ == "__main__":
    server.run(host='0.0.0.0')
